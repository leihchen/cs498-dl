# %%
import os
import time
import math
import glob
import string
import random 
# !conda install torch, torchvision
import torch
import torch.nn as nn
import csv
from rnn.helpers import time_since
# !conda install unidecode
# %matplotlib inline

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Language recognition with an RNN
#
# If you've ever used an online translator you've probably seen a feature that automatically detects the input language. While this might be easy to do if you input unicode characters that are unique to one or a small group of languages (like "你好" or "γεια σας"), this problem is more challenging if the input only uses the available ASCII characters. In this case, something like "těší mě" would beome "tesi me" in the ascii form. This is a more challenging problem in which the language must be recognized purely by the pattern of characters rather than unique unicode characters.
#
# We will train an RNN to solve this problem for a small set of languages thta can be converted to romanized ASCII form. For training data it would be ideal to have a large and varied dataset in different language styles. However, it is easy to find copies of the Bible which is a large text translated to different languages but in the same easily parsable format, so we will use 20 different copies of the Bible as training data. Using the same book for all of the different languages will hopefully prevent minor overfitting that might arise if we used different books for each language (fitting to common characteristics of the individual books rather than the language).

# %%
from unidecode import unidecode as unicodeToAscii

all_characters = string.printable
n_letters = len(all_characters)

print(unicodeToAscii('těší mě'))
# Out:
# tesi me

# %%
# Read a file and split into lines
def readFile(filename):
    data = open(filename, encoding='utf-8').read().strip()
    return unicodeToAscii(data)

def get_category_data(data_path):
    # Build the category_data dictionary, a list of names per language
    category_data = {}
    all_categories = []
    for filename in glob.glob(data_path):
        category = os.path.splitext(os.path.basename(filename))[0].split('_')[0]
        all_categories.append(category)
        data = readFile(filename)
        category_data[category] = data
    
    return category_data, all_categories

# %% [markdown]
# The original text is split into two parts, train and test, so that we can make sure that the model is not simply memorizing the train data.

# %%
train_data_path = 'language_data/train/*_train.txt'
test_data_path = 'language_data/test/*_test.txt'

train_category_data, all_categories = get_category_data(train_data_path)
test_category_data, test_all_categories = get_category_data(test_data_path)

n_languages = len(all_categories)

print(len(all_categories))
print(all_categories)
# Out:
# 20
# ['albanian', 'czech', 'danish', 'english', 'esperanto', 'finnish', 'french', 'german', 'hungarian', 'italian', 'lithuanian', 'maori', 'norwegian', 'portuguese', 'romanian', 'spanish', 'swedish', 'turkish', 'vietnamese', 'xhosa']

# %% [markdown]
# # Data processing

# %%
def categoryFromOutput(output):
    top_n, top_i = output.topk(1, dim=1)
    category_i = top_i[:, 0]
    return category_i

# Turn string into long tensor
def stringToTensor(string):
    tensor = torch.zeros(len(string), requires_grad=True).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return tensor

def load_random_batch(text, chunk_len, batch_size):
    input_data = torch.zeros(batch_size, chunk_len).long().to(device)
    target = torch.zeros(batch_size, 1).long().to(device)
    input_text = []
    for i in range(batch_size):
        category = all_categories[random.randint(0, len(all_categories) - 1)]
        line_start = random.randint(0, len(text[category])-chunk_len)
        category_tensor = torch.tensor([all_categories.index(category)], dtype=torch.long)
        line = text[category][line_start:line_start+chunk_len]
        input_text.append(line)
        input_data[i] = stringToTensor(line)
        target[i] = category_tensor
    return input_data, target, input_text

# %% [markdown]
# Implement Model
# ====================
#
# For this classification task, we can use the same model we implement for the generation task which is located in `rnn/model.py`. See the `MP4_P2_generation.ipynb` notebook for more instructions. In this case each output vector of our RNN will have the dimension of the number of possible languages (i.e. `n_languages`). We will use this vector to predict a distribution over the languages.
#
# In the generation task, we used the output of the RNN at every time step to predict the next letter and our loss included the output from each of these predictions. However, in this task we use the output of the RNN at the end of the sequence to predict the language, so our loss function will use only the predicted output from the last time step.

# %% [markdown]
# # Train RNN

# %%
from rnn.model import RNN

# %%
chunk_len = 50

BATCH_SIZE = 100
n_epochs = 10000
hidden_size = 160
n_layers = 3
learning_rate = 0.0001
model_type = 'lstm'

criterion = nn.CrossEntropyLoss()
rnn = RNN(n_letters, hidden_size, n_languages, model_type=model_type, n_layers=n_layers).to(device)

# %% [markdown]
# **TODO:** Fill in the train function. You should initialize a hidden layer representation using your RNN's `init_hidden` function, set the model gradients to zero, and loop over each time step (character) in the input tensor. For each time step compute the output of the of the RNN and the next hidden layer representation. The cross entropy loss should be computed over the last RNN output scores from the end of the sequence and the target classification tensor. Lastly, call backward on the loss and take an optimizer step.

# %%
def train(rnn, target_tensor, data_tensor, optimizer, criterion, batch_size=BATCH_SIZE):
    """
    Inputs:
    - rnn: model
    - target_target: target character data tensor of shape (batch_size, 1)
    - data_tensor: input character data tensor of shape (batch_size, chunk_len)
    - optimizer: rnn model optimizer
    - criterion: loss function
    - batch_size: data batch size
    
    Returns:
    - output: output from RNN from end of sequence 
    - loss: computed loss value as python float
    
    """
    
    output, loss = None, None
    
    ####################################
    #          YOUR CODE HERE          #
    ####################################
    hidden = rnn.init_hidden(data_tensor.shape[0])
    rnn.zero_grad()
    for i in range(chunk_len):
        output, hidden = rnn(data_tensor[:, i], hidden)
    loss = criterion(output.reshape(batch_size, -1), target_tensor.squeeze())
    loss.backward()
    optimizer.step()
    
    ##########       END      ##########

    return output, loss

# %%
def evaluate(rnn, data_tensor, seq_len=chunk_len, batch_size=BATCH_SIZE):
    with torch.no_grad():
        data_tensor = data_tensor.to(device)
        hidden = rnn.init_hidden(batch_size, device=device)
        for i in range(seq_len):
            output, hidden = rnn(data_tensor[:,i], hidden)
        
        return output
    
def eval_test(rnn, category_tensor, data_tensor):
    with torch.no_grad():
        output = evaluate(rnn, data_tensor)
        loss = criterion(output, category_tensor.squeeze())
        return output, loss.item()

# %%
n_iters = 100000
print_every = 50
plot_every = 50


# Keep track of losses for plotting
current_loss = 0
current_test_loss = 0
all_losses = []
all_test_losses = []

start = time.time()

optimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate)


number_correct = 0
for iter in range(1, n_iters + 1):
    input_data, target_category, text_data = load_random_batch(train_category_data, chunk_len, BATCH_SIZE)
    output, loss = train(rnn, target_category, input_data, optimizer, criterion)
    current_loss += loss
    
    _, test_loss = eval_test(rnn, target_category, input_data)
    current_test_loss += test_loss
    
    guess_i = categoryFromOutput(output)
    number_correct += (target_category.squeeze()==guess_i.squeeze()).long().sum()
    
    # Print iter number, loss, name and guess
    if iter % print_every == 0:
        sample_idx = 0
        guess = all_categories[guess_i[sample_idx]]
        
        category = all_categories[int(target_category[sample_idx])]
        
        correct = '✓' if guess == category else '✗ (%s)' % category
        print('%d %d%% (%s) %.4f %.4f %s / %s %s' % (iter, iter / n_iters * 100, time_since(start), loss, test_loss, text_data[sample_idx], guess, correct))
        print('Train accuracy: {}'.format(float(number_correct)/float(print_every*BATCH_SIZE)))
        number_correct = 0
    
    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0
        all_test_losses.append(current_test_loss / plot_every)
        current_test_loss = 0
    if iter % (print_every*5) == 0:
        eval_batch_size = 1  # needs to be set to 1 for evaluating different sequence lengths

        # Keep track of correct guesses in a confusion matrix
        confusion = torch.zeros(n_languages, n_languages)
        n_confusion = 1000
        num_correct = 0
        total = 0

        for i in range(n_confusion):
            eval_chunk_len = random.randint(10, 50) # in evaluation we will look at sequences of variable sizes
            input_data, target_category, text_data = load_random_batch(test_category_data, chunk_len=eval_chunk_len, batch_size=eval_batch_size)
            output = evaluate(rnn, input_data, seq_len=eval_chunk_len, batch_size=eval_batch_size)

            guess_i = categoryFromOutput(output)
            category_i = [int(target_category[idx]) for idx in range(len(target_category))]
            for j in range(eval_batch_size):
                category = all_categories[category_i[j]] 
                confusion[category_i[j]][guess_i[j]] += 1
                num_correct += int(guess_i[j]==category_i[j])
                total += 1

        print('Test accuracy: ', float(num_correct)/float(n_confusion*eval_batch_size))
        if float(num_correct)/float(n_confusion*eval_batch_size) > .89 or iter == 250:
            torch.save(rnn.state_dict(), './rnn_classifier'+str(iter)+'.pth')
            kaggle_test_file_path = 'language_data/kaggle_rnn_language_classification_test.txt'
            with open(kaggle_test_file_path, 'r') as f:
                lines = f.readlines()

            output_rows = []
            for i, line in enumerate(lines):
                sample = line.rstrip()
                sample_chunk_len = len(sample)
                input_data = stringToTensor(sample).unsqueeze(0)
                output = evaluate(rnn, input_data, seq_len=sample_chunk_len, batch_size=1)
                guess_i = categoryFromOutput(output)
                output_rows.append((str(i+1), all_categories[guess_i]))

            submission_file_path = 'kaggle_rnn_submission'+str(iter)+'.txt'
            with open(submission_file_path, 'w') as f:
                output_rows = [('id', 'category')] + output_rows
                writer = csv.writer(f)
                writer.writerows(output_rows)
# Out:
# 50 1% (0m 24s) 1.9003 1.8448 nului, Dumnezeului lui Israel``. ,,Pe vremea lui S / romanian ✓
# Train accuracy: 0.202
# 100 2% (0m 50s) 1.1458 1.1115 do desde mi mocedad. Entonces Jesus mirandole, amo / spanish ✓
# Train accuracy: 0.5316
# 150 3% (1m 17s) 0.7924 0.7167 azen e altarit. Do te marre tere dhjamin e tij, as / albanian ✓
# Train accuracy: 0.6728
# 200 5% (1m 45s) 0.7517 0.7023 e: "Paasta poika minun mukaani, niin me lahdemme m / finnish ✓
# Train accuracy: 0.7462
# 250 6% (2m 15s) 0.6134 0.5771 er sig mod HERRENs Helliggaver, skal han til Bod d / danish ✓
# Train accuracy: 0.7882
# Test accuracy:  0.638
# 300 7% (3m 47s) 0.7452 0.7062 d, as in the days of old, saith Jehovah. But fear  / english ✓
# Train accuracy: 0.8102
# 350 8% (4m 21s) 0.4047 0.3535 on till honom: >>Se, din moder och dina broder sta / swedish ✓
# Train accuracy: 0.8402
# 400 10% (4m 55s) 0.4130 0.3668 na vardu Orpa, o kitaRuta. Jie ten isgyveno apie d / finnish ✗ (lithuanian)
# Train accuracy: 0.8644
# 450 11% (5m 31s) 0.2446 0.2083 ella sua vigna. Ed uscito verso l'ora terza, ne vi / spanish ✗ (italian)
# Train accuracy: 0.8704
# 500 12% (6m 9s) 0.2521 0.2398 ;  cxar sxi kasxis la senditojn, kiujn Josuo sendi / esperanto ✓
# Train accuracy: 0.8808
# Test accuracy:  0.727
# 550 13% (6m 59s) 0.2222 0.2043 ad skal jeg stille dig lige, Jerusalems Datter, hv / danish ✓
# Train accuracy: 0.8966
# 600 15% (7m 42s) 0.2645 0.2100 folket horde det: >>Tagen eder till vara for de sk / swedish ✓
# Train accuracy: 0.905
# 650 16% (8m 27s) 0.3770 0.3508 sen poikasi kadesta. En myoskaan riista pojaltasi  / finnish ✓
# Train accuracy: 0.913
# 700 17% (9m 15s) 0.2321 0.1813 e fluchtige Schlange. Siehe, das sind die Umrisse  / german ✓
# Train accuracy: 0.9134
# 750 18% (10m 6s) 0.0925 0.0824 Sa chair prend plus de fraicheur que dans son enfa / french ✓
# Train accuracy: 0.9298
# Test accuracy:  0.762
# 800 20% (11m 10s) 0.2116 0.1995  los Asirios: pues lo redujo a estrechez, y no lo  / spanish ✓
# Train accuracy: 0.9374
# 850 21% (12m 6s) 0.2158 0.2018  til jern, og dine klover vil jeg gjore til kobber / norwegian ✓
# Train accuracy: 0.9376
# 900 22% (13m 5s) 0.2772 0.2438 pki bize verdigi gibi onlara da vermekle, onlari k / turkish ✓
# Train accuracy: 0.937
# 950 23% (14m 6s) 0.1588 0.1395 ders profeter, de som profeterte for eder og sa: B / norwegian ✓
# Train accuracy: 0.9436
# 1000 25% (15m 9s) 0.1278 0.1037  Sitie buvo karaliaus Dovydo nuosavybes vyriausiej / lithuanian ✓
# Train accuracy: 0.945
# Test accuracy:  0.77
# 1050 26% (16m 26s) 0.1389 0.1183 ileyo, aqingqwe ngokomlinganiso, asarhiweyo ngeesa / xhosa ✓
# Train accuracy: 0.9474
# 1100 27% (17m 34s) 0.1203 0.1087 menjen el veled, az ne [is] menjen. Es levezette a / hungarian ✓
# Train accuracy: 0.9526
# 1150 28% (18m 45s) 0.1420 0.1130  nun hin, arbeitet; Stroh soll man euch nicht gebe / german ✓
# Train accuracy: 0.9504
# 1200 30% (19m 58s) 0.1292 0.1255 uxaj partoj estis turnitaj internen. GXi havis la  / esperanto ✓
# Train accuracy: 0.9622
# 1250 31% (21m 14s) 0.0885 0.0582 rve, kazdy vlastni pazi. Otce i matku v tobe zlehc / czech ✓
# Train accuracy: 0.959
# Test accuracy:  0.797
# 1300 32% (22m 42s) 0.1334 0.0928 enger; jeg vil ikke ofre Herren min Gud brennoffer / norwegian ✓
# Train accuracy: 0.9594
# 1350 33% (24m 2s) 0.1306 0.0917 raniero che soggiorna in mezzo a loro, perche tutt / italian ✓
# Train accuracy: 0.959
# 1400 35% (25m 24s) 0.0787 0.0734 ; es vilagossag lakozik vele! Neked adok halat, at / hungarian ✓
# Train accuracy: 0.965
# 1450 36% (26m 49s) 0.0688 0.0569 t before them that sit here, and before the elders / english ✓
# Train accuracy: 0.965
# 1500 37% (28m 15s) 0.1144 0.0888 zraky vseho lidu, stal totiz vyse nez ostatni lid. / czech ✓
# Train accuracy: 0.9628
# Test accuracy:  0.799
# 1550 38% (29m 55s) 0.0830 0.0623 salah war 187 Jahre alt, als er den Lamech zeugte; / german ✓
# Train accuracy: 0.966
# 1600 40% (31m 28s) 0.1056 0.0951 nger to, men ett kjod. Derfor, det som Gud har sam / norwegian ✓
# Train accuracy: 0.9656
# 1650 41% (33m 3s) 0.0698 0.0461  elfoglala o tole egynehany varost, Bethelt es ann / hungarian ✓
# Train accuracy: 0.962
# 1700 42% (34m 40s) 0.1295 0.1099 es rot ratne, og deres blomst fare op som stov; fo / norwegian ✓
# Train accuracy: 0.9654
# 1750 43% (36m 21s) 0.1017 0.0829 a a jen o to budu usilovat: abych v dome Hospodino / czech ✓
# Train accuracy: 0.9722
# Test accuracy:  0.812
# 1800 45% (38m 15s) 0.0389 0.0286 Is tiesu, is tiesu sakau jums: pirmiau, negu buvo  / lithuanian ✓
# Train accuracy: 0.9758
# 1850 46% (40m 1s) 0.0466 0.0309 gelied an uber den Konig zu Tyrus und sprich zu ih / german ✓
# Train accuracy: 0.9676
# 1900 47% (41m 50s) 0.0960 0.0775 li ithi, Umbono awubonayo yena lo, ngowemihla emin / xhosa ✓
# Train accuracy: 0.9712
# 1950 48% (43m 41s) 0.1235 0.1117 r; de vendte sig ikke, nar de gik. Videre skuede j / danish ✓
# Train accuracy: 0.9744
# 2000 50% (45m 36s) 0.0554 0.0518 eyi bildigini anliyoruz. Kimsenin sana soru sormas / turkish ✓
# Train accuracy: 0.9762
# Test accuracy:  0.841
# 2050 51% (47m 44s) 0.0644 0.0455 nga-va toate uriciunile voastre, casa lui Israel!  / romanian ✓
# Train accuracy: 0.9806
# 2100 52% (49m 46s) 0.0062 0.0058 et Samuel, >>ty>>, sade hon, >>av HERREN har jag u / swedish ✓
# Train accuracy: 0.9802
# 2150 53% (51m 53s) 0.1113 0.1014  piu prossimo verra, e riscattera cio che il suo f / italian ✓
# Train accuracy: 0.9812
# 2200 55% (54m 5s) 0.0485 0.0236 rhed, hans staerke Hand og udstrakte Arm, hans Teg / danish ✓
# Train accuracy: 0.9762
# 2250 56% (56m 21s) 0.0140 0.0090 eat deal, Thou son of David, have mercy on me. And / english ✓
# Train accuracy: 0.979
# Test accuracy:  0.841
# 2300 57% (58m 50s) 0.0181 0.0152  mig med dig rattfardighet och ratt, i nad och bar / swedish ✓
# Train accuracy: 0.9784
# 2350 58% (61m 18s) 0.0366 0.0252 il ne se fie pas a ses serviteurs, il trouve des d / french ✓
# Train accuracy: 0.9766
# 2400 60% (63m 46s) 0.0370 0.0303 ano ranei ia ki a ia? E kore ianei taua whenua e p / maori ✓
# Train accuracy: 0.9782
# 2450 61% (66m 16s) 0.0189 0.0171 tten til Gift og Retfaerds Frugt til Malurt; I gla / danish ✓
# Train accuracy: 0.9806
# 2500 62% (68m 49s) 0.0446 0.0323 u para que se cumprisse o que foi dito pelo profet / italian ✗ (portuguese)
# Train accuracy: 0.9762
# Test accuracy:  0.837
# Test accuracy:  0.843
# Test accuracy:  0.866
# Test accuracy:  0.873
# Test accuracy:  0.862
# Test accuracy:  0.84
# Test accuracy:  0.867
# Test accuracy:  0.848
# Test accuracy:  0.853
# Test accuracy:  0.858
# Test accuracy:  0.849
# Test accuracy:  0.834
# Test accuracy:  0.873
# Test accuracy:  0.836
# Test accuracy:  0.833
# Test accuracy:  0.815
# Test accuracy:  0.847
# Test accuracy:  0.865
# Test accuracy:  0.836
# Test accuracy:  0.823
# Test accuracy:  0.841
# Test accuracy:  0.85
# Test accuracy:  0.843
# Test accuracy:  0.85
# Test accuracy:  0.823
# Test accuracy:  0.837
# Test accuracy:  0.847
# Test accuracy:  0.839
# Test accuracy:  0.854
# Test accuracy:  0.845
# Test accuracy:  0.868
# Test accuracy:  0.854
# Test accuracy:  0.836
# Test accuracy:  0.85
# Test accuracy:  0.839
# Test accuracy:  0.834
# Test accuracy:  0.845
# Test accuracy:  0.851
# Test accuracy:  0.831
# Test accuracy:  0.859
# Test accuracy:  0.868
# Test accuracy:  0.831
# Test accuracy:  0.841
# Test accuracy:  0.843
# Test accuracy:  0.861
# Test accuracy:  0.834
# Test accuracy:  0.858
# Test accuracy:  0.865
# Test accuracy:  0.846
# Test accuracy:  0.837
# 2550 63% (80m 2s) 0.0505 0.0368 bs Gud er var faste borg. Sela. Til sangmesteren;  / norwegian ✓
# Train accuracy: 0.9816
# Test accuracy:  0.837
# Test accuracy:  0.842
# Test accuracy:  0.848
# Test accuracy:  0.835
# Test accuracy:  0.835
# Test accuracy:  0.814
# Test accuracy:  0.845
# Test accuracy:  0.857
# Test accuracy:  0.863
# Test accuracy:  0.852
# Test accuracy:  0.863
# Test accuracy:  0.855
# Test accuracy:  0.855
# Test accuracy:  0.848
# Test accuracy:  0.846
# Test accuracy:  0.861
# Test accuracy:  0.848
# Test accuracy:  0.873
# Test accuracy:  0.854
# Test accuracy:  0.862
# Test accuracy:  0.858
# Test accuracy:  0.859
# Test accuracy:  0.841
# Test accuracy:  0.865
# Test accuracy:  0.852
# Test accuracy:  0.845
# Test accuracy:  0.863
# Test accuracy:  0.866
# Test accuracy:  0.834
# Test accuracy:  0.858
# Test accuracy:  0.863
# Test accuracy:  0.828
# Test accuracy:  0.849
# Test accuracy:  0.87
# Test accuracy:  0.874
# Test accuracy:  0.851
# Test accuracy:  0.853
# Test accuracy:  0.856
# Test accuracy:  0.856
# Test accuracy:  0.842
# Test accuracy:  0.853
# Test accuracy:  0.853
# Test accuracy:  0.83
# Test accuracy:  0.863
# Test accuracy:  0.852
# Test accuracy:  0.844
# Test accuracy:  0.834
# Test accuracy:  0.832
# Test accuracy:  0.83
# Test accuracy:  0.856
# 2600 65% (91m 24s) 0.0432 0.0410 RRN dienen, das Hochheilige essen sollen; daselbst / german ✓
# Train accuracy: 0.981
# Test accuracy:  0.857
# Test accuracy:  0.852
# Test accuracy:  0.839
# Test accuracy:  0.843
# Test accuracy:  0.852
# Test accuracy:  0.834
# Test accuracy:  0.861
# Test accuracy:  0.825
# Test accuracy:  0.848
# Test accuracy:  0.834
# Test accuracy:  0.829
# Test accuracy:  0.857
# Test accuracy:  0.854
# Test accuracy:  0.825
# Test accuracy:  0.868
# Test accuracy:  0.849
# Test accuracy:  0.843
# Test accuracy:  0.844
# Test accuracy:  0.861
# Test accuracy:  0.844
# Test accuracy:  0.832
# Test accuracy:  0.834
# Test accuracy:  0.842
# Test accuracy:  0.836
# Test accuracy:  0.84
# Test accuracy:  0.824
# Test accuracy:  0.838
# Test accuracy:  0.846
# Test accuracy:  0.864
# Test accuracy:  0.85
# Test accuracy:  0.848
# Test accuracy:  0.846
# Test accuracy:  0.831
# Test accuracy:  0.845
# Test accuracy:  0.851
# Test accuracy:  0.85
# Test accuracy:  0.833
# Test accuracy:  0.857
# Test accuracy:  0.849
# Test accuracy:  0.852
# Test accuracy:  0.848
# Test accuracy:  0.862
# Test accuracy:  0.839
# Test accuracy:  0.847
# Test accuracy:  0.837
# Test accuracy:  0.844
# Test accuracy:  0.854
# Test accuracy:  0.862
# Test accuracy:  0.861
# Test accuracy:  0.851
# 2650 66% (102m 52s) 0.0387 0.0279 prisel do jeho domu, protoze mel jedinou dceru, as / czech ✓
# Train accuracy: 0.9776
# Test accuracy:  0.871
# Test accuracy:  0.847
# Test accuracy:  0.836
# Test accuracy:  0.856
# Test accuracy:  0.845
# Test accuracy:  0.859
# Test accuracy:  0.852
# Test accuracy:  0.857
# Test accuracy:  0.861
# Test accuracy:  0.829
# Test accuracy:  0.85
# Test accuracy:  0.862
# Test accuracy:  0.842
# Test accuracy:  0.845
# Test accuracy:  0.854
# Test accuracy:  0.848
# Test accuracy:  0.851
# Test accuracy:  0.841
# Test accuracy:  0.85
# Test accuracy:  0.863
# Test accuracy:  0.825
# Test accuracy:  0.853
# Test accuracy:  0.826
# Test accuracy:  0.854
# Test accuracy:  0.865
# Test accuracy:  0.866
# Test accuracy:  0.859
# Test accuracy:  0.864
# Test accuracy:  0.858
# Test accuracy:  0.858
# Test accuracy:  0.858
# Test accuracy:  0.87
# Test accuracy:  0.833
# Test accuracy:  0.838
# Test accuracy:  0.852
# Test accuracy:  0.858
# Test accuracy:  0.844
# Test accuracy:  0.855
# Test accuracy:  0.866
# Test accuracy:  0.832
# Test accuracy:  0.837
# Test accuracy:  0.861
# Test accuracy:  0.862
# Test accuracy:  0.852
# Test accuracy:  0.863
# Test accuracy:  0.826
# Test accuracy:  0.852
# Test accuracy:  0.851
# Test accuracy:  0.834
# Test accuracy:  0.88
# 2700 67% (114m 18s) 0.1004 0.0888 rs vilde jeg gi dig det; i brennoffer har du ikke  / norwegian ✓
# Train accuracy: 0.9772
# Test accuracy:  0.853
# Test accuracy:  0.856
# Test accuracy:  0.853
# Test accuracy:  0.87
# Test accuracy:  0.861
# Test accuracy:  0.85
# Test accuracy:  0.864
# Test accuracy:  0.86
# Test accuracy:  0.868
# Test accuracy:  0.842
# Test accuracy:  0.834
# Test accuracy:  0.832
# Test accuracy:  0.851
# Test accuracy:  0.846
# Test accuracy:  0.861
# Test accuracy:  0.884
# Test accuracy:  0.877
# Test accuracy:  0.838
# Test accuracy:  0.863
# Test accuracy:  0.848
# Test accuracy:  0.845
# Test accuracy:  0.858
# Test accuracy:  0.865
# Test accuracy:  0.856
# Test accuracy:  0.85
# Test accuracy:  0.86
# Test accuracy:  0.85
# Test accuracy:  0.825
# Test accuracy:  0.848
# Test accuracy:  0.847
# Test accuracy:  0.855
# Test accuracy:  0.864
# Test accuracy:  0.848
# Test accuracy:  0.868
# Test accuracy:  0.855
# Test accuracy:  0.855
# Test accuracy:  0.844
# Test accuracy:  0.847
# Test accuracy:  0.87
# Test accuracy:  0.866
# Test accuracy:  0.861
# Test accuracy:  0.862
# Test accuracy:  0.85
# Test accuracy:  0.857
# Test accuracy:  0.87
# Test accuracy:  0.842
# Test accuracy:  0.873
# Test accuracy:  0.873
# Test accuracy:  0.867
# Test accuracy:  0.863
# 2750 68% (125m 36s) 0.1117 0.0633 r ikke apenbaret dig det, men min Fader i himmelen / danish ✗ (norwegian)
# Train accuracy: 0.9836
# Test accuracy:  0.862
# Test accuracy:  0.856
# Test accuracy:  0.858
# Test accuracy:  0.847
# Test accuracy:  0.871
# Test accuracy:  0.851
# Test accuracy:  0.863
# Test accuracy:  0.86
# Test accuracy:  0.844
# Test accuracy:  0.839
# Test accuracy:  0.847
# Test accuracy:  0.848
# Test accuracy:  0.836
# Test accuracy:  0.837
# Test accuracy:  0.834
# Test accuracy:  0.835
# Test accuracy:  0.861
# Test accuracy:  0.835
# Test accuracy:  0.831
# Test accuracy:  0.837
# Test accuracy:  0.855
# Test accuracy:  0.864
# Test accuracy:  0.848
# Test accuracy:  0.862
# Test accuracy:  0.866
# Test accuracy:  0.861
# Test accuracy:  0.847
# Test accuracy:  0.866
# Test accuracy:  0.869
# Test accuracy:  0.884
# Test accuracy:  0.845
# Test accuracy:  0.851
# Test accuracy:  0.856
# Test accuracy:  0.872
# Test accuracy:  0.873
# Test accuracy:  0.873
# Test accuracy:  0.871
# Test accuracy:  0.873
# Test accuracy:  0.864
# Test accuracy:  0.848
# Test accuracy:  0.844
# Test accuracy:  0.86
# Test accuracy:  0.854
# Test accuracy:  0.863
# Test accuracy:  0.868
# Test accuracy:  0.848
# Test accuracy:  0.847
# Test accuracy:  0.849
# Test accuracy:  0.865
# Test accuracy:  0.855
# 2800 70% (136m 56s) 0.0287 0.0233 do teu proximo. Quando um homem tomar uma mulher e / portuguese ✓
# Train accuracy: 0.9856
# Test accuracy:  0.847
# Test accuracy:  0.858
# Test accuracy:  0.819
# Test accuracy:  0.842
# Test accuracy:  0.841
# Test accuracy:  0.846
# Test accuracy:  0.828
# Test accuracy:  0.825
# Test accuracy:  0.853
# Test accuracy:  0.855
# Test accuracy:  0.88
# Test accuracy:  0.849
# Test accuracy:  0.852
# Test accuracy:  0.841
# Test accuracy:  0.848
# Test accuracy:  0.854
# Test accuracy:  0.847
# Test accuracy:  0.854
# Test accuracy:  0.862
# Test accuracy:  0.862
# Test accuracy:  0.875
# Test accuracy:  0.853
# Test accuracy:  0.86
# Test accuracy:  0.875
# Test accuracy:  0.857
# Test accuracy:  0.87
# Test accuracy:  0.874
# Test accuracy:  0.852
# Test accuracy:  0.869
# Test accuracy:  0.862
# Test accuracy:  0.86
# Test accuracy:  0.858
# Test accuracy:  0.867
# Test accuracy:  0.87
# Test accuracy:  0.855
# Test accuracy:  0.854
# Test accuracy:  0.854
# Test accuracy:  0.854
# Test accuracy:  0.848
# Test accuracy:  0.858
# Test accuracy:  0.847
# Test accuracy:  0.84
# Test accuracy:  0.861
# Test accuracy:  0.868
# Test accuracy:  0.864
# Test accuracy:  0.858
# Test accuracy:  0.83
# Test accuracy:  0.839
# Test accuracy:  0.853
# Test accuracy:  0.858
# 2850 71% (148m 19s) 0.1045 0.0806 nem jojjenek ok maguk es vezessenek ki minket. A p / hungarian ✓
# Train accuracy: 0.9804
# Test accuracy:  0.871
# Test accuracy:  0.862
# Test accuracy:  0.846
# Test accuracy:  0.86
# Test accuracy:  0.848
# Test accuracy:  0.858
# Test accuracy:  0.877
# Test accuracy:  0.849
# Test accuracy:  0.853
# Test accuracy:  0.851
# Test accuracy:  0.864
# Test accuracy:  0.858
# Test accuracy:  0.861
# Test accuracy:  0.834
# Test accuracy:  0.865
# Test accuracy:  0.838
# Test accuracy:  0.842
# Test accuracy:  0.837
# Test accuracy:  0.838
# Test accuracy:  0.861
# Test accuracy:  0.822
# Test accuracy:  0.83
# Test accuracy:  0.837
# Test accuracy:  0.851
# Test accuracy:  0.838
# Test accuracy:  0.848
# Test accuracy:  0.839
# Test accuracy:  0.863
# Test accuracy:  0.852
# Test accuracy:  0.831
# Test accuracy:  0.842
# Test accuracy:  0.832
# Test accuracy:  0.837
# Test accuracy:  0.868
# Test accuracy:  0.843
# Test accuracy:  0.866
# Test accuracy:  0.828
# Test accuracy:  0.868
# Test accuracy:  0.844
# Test accuracy:  0.866
# Test accuracy:  0.869
# Test accuracy:  0.869
# Test accuracy:  0.861
# Test accuracy:  0.844
# Test accuracy:  0.87
# Test accuracy:  0.857
# Test accuracy:  0.847
# Test accuracy:  0.851
# Test accuracy:  0.856
# Test accuracy:  0.85
# 2900 72% (159m 46s) 0.0345 0.0263 ato qe i pelqejne atij. Pastaj ti do t'ia cosh bab / albanian ✓
# Train accuracy: 0.9802
# Test accuracy:  0.866
# Test accuracy:  0.867
# Test accuracy:  0.875
# Test accuracy:  0.84
# Test accuracy:  0.842
# Test accuracy:  0.864
# Test accuracy:  0.877
# Test accuracy:  0.841
# Test accuracy:  0.867
# Test accuracy:  0.838
# Test accuracy:  0.854
# Test accuracy:  0.857
# Test accuracy:  0.854
# Test accuracy:  0.851
# Test accuracy:  0.84
# Test accuracy:  0.849
# Test accuracy:  0.844
# Test accuracy:  0.844
# Test accuracy:  0.86
# Test accuracy:  0.86
# Test accuracy:  0.851
# Test accuracy:  0.879
# Test accuracy:  0.851
# Test accuracy:  0.869
# Test accuracy:  0.833
# Test accuracy:  0.832
# Test accuracy:  0.847
# Test accuracy:  0.866
# Test accuracy:  0.843
# Test accuracy:  0.855
# Test accuracy:  0.856
# Test accuracy:  0.862
# Test accuracy:  0.873
# Test accuracy:  0.876
# Test accuracy:  0.867
# Test accuracy:  0.867
# Test accuracy:  0.863
# Test accuracy:  0.851
# Test accuracy:  0.849
# Test accuracy:  0.855
# Test accuracy:  0.854
# Test accuracy:  0.859
# Test accuracy:  0.834
# Test accuracy:  0.849
# Test accuracy:  0.848
# Test accuracy:  0.878
# Test accuracy:  0.872
# Test accuracy:  0.844
# Test accuracy:  0.855
# Test accuracy:  0.855
# 2950 73% (171m 30s) 0.0097 0.0095 hoang cho Duc Chua Troi chung ta! Moi noi sung tha / vietnamese ✓
# Train accuracy: 0.9832
# Test accuracy:  0.862
# Test accuracy:  0.843
# Test accuracy:  0.869
# Test accuracy:  0.869
# Test accuracy:  0.848
# Test accuracy:  0.843
# Test accuracy:  0.847
# Test accuracy:  0.867
# Test accuracy:  0.853
# Test accuracy:  0.855
# Test accuracy:  0.848
# Test accuracy:  0.829
# Test accuracy:  0.865
# Test accuracy:  0.861
# Test accuracy:  0.871
# Test accuracy:  0.847
# Test accuracy:  0.871
# Test accuracy:  0.869
# Test accuracy:  0.851
# Test accuracy:  0.848
# Test accuracy:  0.852
# Test accuracy:  0.865
# Test accuracy:  0.862
# Test accuracy:  0.835
# Test accuracy:  0.84
# Test accuracy:  0.847
# Test accuracy:  0.86
# Test accuracy:  0.863
# Test accuracy:  0.843
# Test accuracy:  0.849
# Test accuracy:  0.838
# Test accuracy:  0.847
# Test accuracy:  0.846
# Test accuracy:  0.835
# Test accuracy:  0.847
# Test accuracy:  0.838
# Test accuracy:  0.872
# Test accuracy:  0.853
# Test accuracy:  0.875
# Test accuracy:  0.85
# Test accuracy:  0.851
# Test accuracy:  0.837
# Test accuracy:  0.867
# Test accuracy:  0.867
# Test accuracy:  0.854
# Test accuracy:  0.857
# Test accuracy:  0.847
# Test accuracy:  0.885
# Test accuracy:  0.845
# Test accuracy:  0.881
# 3000 75% (183m 9s) 0.0465 0.0434 hvad Gud vil gjore med mig! Og han forte dem frem  / norwegian ✓
# Train accuracy: 0.981
# Test accuracy:  0.854
# Test accuracy:  0.853
# Test accuracy:  0.854
# Test accuracy:  0.867
# Test accuracy:  0.854
# Test accuracy:  0.86
# Test accuracy:  0.865
# Test accuracy:  0.877
# Test accuracy:  0.868
# Test accuracy:  0.87
# Test accuracy:  0.869
# Test accuracy:  0.875
# Test accuracy:  0.878
# Test accuracy:  0.847
# Test accuracy:  0.869
# Test accuracy:  0.867
# Test accuracy:  0.865
# Test accuracy:  0.852
# Test accuracy:  0.866
# Test accuracy:  0.85
# Test accuracy:  0.843
# Test accuracy:  0.853
# Test accuracy:  0.876
# Test accuracy:  0.854
# Test accuracy:  0.845
# Test accuracy:  0.858
# Test accuracy:  0.859
# Test accuracy:  0.855
# Test accuracy:  0.88
# Test accuracy:  0.853
# Test accuracy:  0.856
# Test accuracy:  0.862
# Test accuracy:  0.853
# Test accuracy:  0.858
# Test accuracy:  0.847
# Test accuracy:  0.866
# Test accuracy:  0.872
# Test accuracy:  0.867
# Test accuracy:  0.864
# Test accuracy:  0.877
# Test accuracy:  0.874
# Test accuracy:  0.877
# Test accuracy:  0.858
# Test accuracy:  0.863
# Test accuracy:  0.866
# Test accuracy:  0.853
# Test accuracy:  0.867
# Test accuracy:  0.877
# Test accuracy:  0.871
# Test accuracy:  0.856
# 3050 76% (194m 45s) 0.0299 0.0243 oldugumu anlayacak.>> Daglari asip gelen mujdecini / turkish ✓
# Train accuracy: 0.9812
# Test accuracy:  0.862
# Test accuracy:  0.861
# Test accuracy:  0.857
# Test accuracy:  0.854
# Test accuracy:  0.84
# Test accuracy:  0.867
# Test accuracy:  0.841
# Test accuracy:  0.861
# Test accuracy:  0.847
# Test accuracy:  0.872
# Test accuracy:  0.866
# Test accuracy:  0.855
# Test accuracy:  0.849
# Test accuracy:  0.844
# Test accuracy:  0.882
# Test accuracy:  0.879
# Test accuracy:  0.875
# Test accuracy:  0.882
# Test accuracy:  0.853
# Test accuracy:  0.863
# Test accuracy:  0.872
# Test accuracy:  0.878
# Test accuracy:  0.864
# Test accuracy:  0.859
# Test accuracy:  0.855
# Test accuracy:  0.867
# Test accuracy:  0.86
# Test accuracy:  0.86
# Test accuracy:  0.829
# Test accuracy:  0.868
# Test accuracy:  0.869
# Test accuracy:  0.879
# Test accuracy:  0.85
# Test accuracy:  0.854
# Test accuracy:  0.864
# Test accuracy:  0.856
# Test accuracy:  0.862
# Test accuracy:  0.845
# Test accuracy:  0.858
# Test accuracy:  0.873
# Test accuracy:  0.853
# Test accuracy:  0.856
# Test accuracy:  0.878
# Test accuracy:  0.844
# Test accuracy:  0.837
# Test accuracy:  0.863
# Test accuracy:  0.853
# Test accuracy:  0.855
# Test accuracy:  0.863
# Test accuracy:  0.853
# 3100 77% (206m 28s) 0.0234 0.0145 ai colto in flagrante delitto di scasso; eppure, d / italian ✓
# Train accuracy: 0.985
# Test accuracy:  0.846
# Test accuracy:  0.828
# Test accuracy:  0.862
# Test accuracy:  0.855
# Test accuracy:  0.856
# Test accuracy:  0.869
# Test accuracy:  0.872
# Test accuracy:  0.845
# Test accuracy:  0.846
# Test accuracy:  0.87
# Test accuracy:  0.862
# Test accuracy:  0.859
# Test accuracy:  0.875
# Test accuracy:  0.87
# Test accuracy:  0.858
# Test accuracy:  0.842
# Test accuracy:  0.841
# Test accuracy:  0.825
# Test accuracy:  0.835
# Test accuracy:  0.849
# Test accuracy:  0.851
# Test accuracy:  0.857
# Test accuracy:  0.855
# Test accuracy:  0.843
# Test accuracy:  0.869
# Test accuracy:  0.873
# Test accuracy:  0.852
# Test accuracy:  0.875
# Test accuracy:  0.866
# Test accuracy:  0.861
# Test accuracy:  0.844
# Test accuracy:  0.837
# Test accuracy:  0.867
# Test accuracy:  0.852
# Test accuracy:  0.87
# Test accuracy:  0.86
# Test accuracy:  0.862
# Test accuracy:  0.853
# Test accuracy:  0.851
# Test accuracy:  0.88
# Test accuracy:  0.876
# Test accuracy:  0.82
# Test accuracy:  0.872
# Test accuracy:  0.861
# Test accuracy:  0.847
# Test accuracy:  0.871
# Test accuracy:  0.875
# Test accuracy:  0.854
# Test accuracy:  0.879
# Test accuracy:  0.861
# 3150 78% (218m 15s) 0.1343 0.1163 ni,<br />Kildan ulkesine karsi ne amacladigini isi / turkish ✓
# Train accuracy: 0.9806
# Test accuracy:  0.87
# Test accuracy:  0.859
# Test accuracy:  0.853
# Test accuracy:  0.86
# Test accuracy:  0.857
# Test accuracy:  0.85
# Test accuracy:  0.85
# Test accuracy:  0.885
# Test accuracy:  0.848
# Test accuracy:  0.863
# Test accuracy:  0.866
# Test accuracy:  0.843
# Test accuracy:  0.842
# Test accuracy:  0.855
# Test accuracy:  0.853
# Test accuracy:  0.825
# Test accuracy:  0.832
# Test accuracy:  0.862
# Test accuracy:  0.849
# Test accuracy:  0.847
# Test accuracy:  0.842
# Test accuracy:  0.851
# Test accuracy:  0.835
# Test accuracy:  0.846
# Test accuracy:  0.858
# Test accuracy:  0.868
# Test accuracy:  0.861
# Test accuracy:  0.857
# Test accuracy:  0.851
# Test accuracy:  0.861
# Test accuracy:  0.856
# Test accuracy:  0.847
# Test accuracy:  0.862
# Test accuracy:  0.842
# Test accuracy:  0.845
# Test accuracy:  0.837
# Test accuracy:  0.855
# Test accuracy:  0.854
# Test accuracy:  0.867
# Test accuracy:  0.831
# Test accuracy:  0.837
# Test accuracy:  0.855
# Test accuracy:  0.856
# Test accuracy:  0.85
# Test accuracy:  0.851
# Test accuracy:  0.844
# Test accuracy:  0.863
# Test accuracy:  0.836
# Test accuracy:  0.848
# Test accuracy:  0.843
# 3200 80% (229m 59s) 0.0451 0.0422 la punta dell'altra. Il secondo cherubino era pari / italian ✓
# Train accuracy: 0.9822
# Test accuracy:  0.865
# Test accuracy:  0.855
# Test accuracy:  0.851
# Test accuracy:  0.814
# Test accuracy:  0.84
# Test accuracy:  0.841
# Test accuracy:  0.834
# Test accuracy:  0.839
# Test accuracy:  0.857
# Test accuracy:  0.861
# Test accuracy:  0.847
# Test accuracy:  0.858
# Test accuracy:  0.872
# Test accuracy:  0.864
# Test accuracy:  0.848
# Test accuracy:  0.852
# Test accuracy:  0.838
# Test accuracy:  0.834
# Test accuracy:  0.843
# Test accuracy:  0.849
# Test accuracy:  0.847
# Test accuracy:  0.848
# Test accuracy:  0.829
# Test accuracy:  0.829
# Test accuracy:  0.848
# Test accuracy:  0.835
# Test accuracy:  0.87
# Test accuracy:  0.843
# Test accuracy:  0.85
# Test accuracy:  0.844
# Test accuracy:  0.847
# Test accuracy:  0.849
# Test accuracy:  0.864
# Test accuracy:  0.845
# Test accuracy:  0.844
# Test accuracy:  0.842
# Test accuracy:  0.852
# Test accuracy:  0.846
# Test accuracy:  0.864
# Test accuracy:  0.857
# Test accuracy:  0.859
# Test accuracy:  0.851
# Test accuracy:  0.865
# Test accuracy:  0.852
# Test accuracy:  0.854
# Test accuracy:  0.857
# Test accuracy:  0.864
# Test accuracy:  0.87
# Test accuracy:  0.854
# Test accuracy:  0.854
# 3250 81% (241m 38s) 0.0178 0.0129 or the continual showbread, and for the burnt-offe / english ✓
# Train accuracy: 0.9776
# Test accuracy:  0.865
# Test accuracy:  0.853
# Test accuracy:  0.865
# Test accuracy:  0.871
# Test accuracy:  0.864
# Test accuracy:  0.867
# Test accuracy:  0.855
# Test accuracy:  0.859
# Test accuracy:  0.851
# Test accuracy:  0.86
# Test accuracy:  0.855
# Test accuracy:  0.864
# Test accuracy:  0.863
# Test accuracy:  0.834
# Test accuracy:  0.863
# Test accuracy:  0.849
# Test accuracy:  0.848
# Test accuracy:  0.852
# Test accuracy:  0.879
# Test accuracy:  0.858
# Test accuracy:  0.852
# Test accuracy:  0.874
# Test accuracy:  0.851
# Test accuracy:  0.86
# Test accuracy:  0.858
# Test accuracy:  0.87
# Test accuracy:  0.863
# Test accuracy:  0.866
# Test accuracy:  0.855
# Test accuracy:  0.882
# Test accuracy:  0.862
# Test accuracy:  0.859
# Test accuracy:  0.857
# Test accuracy:  0.867
# Test accuracy:  0.867
# Test accuracy:  0.859
# Test accuracy:  0.855
# Test accuracy:  0.856
# Test accuracy:  0.869
# Test accuracy:  0.867
# Test accuracy:  0.85
# Test accuracy:  0.87
# Test accuracy:  0.887
# Test accuracy:  0.857
# Test accuracy:  0.886
# Test accuracy:  0.873
# Test accuracy:  0.88
# Test accuracy:  0.868
# Test accuracy:  0.88
# Test accuracy:  0.86
# 3300 82% (253m 21s) 0.0548 0.0441 r wollen doch den HERRN, unsern Gott, furchten, de / german ✓
# Train accuracy: 0.9876
# Test accuracy:  0.869
# Test accuracy:  0.869
# Test accuracy:  0.834
# Test accuracy:  0.86
# Test accuracy:  0.866
# Test accuracy:  0.882
# Test accuracy:  0.877
# Test accuracy:  0.847
# Test accuracy:  0.886
# Test accuracy:  0.851
# Test accuracy:  0.86
# Test accuracy:  0.873
# Test accuracy:  0.86
# Test accuracy:  0.878
# Test accuracy:  0.867
# Test accuracy:  0.852
# Test accuracy:  0.863
# Test accuracy:  0.862
# Test accuracy:  0.843
# Test accuracy:  0.863
# Test accuracy:  0.865
# Test accuracy:  0.847
# Test accuracy:  0.875
# Test accuracy:  0.878
# Test accuracy:  0.86
# Test accuracy:  0.849
# Test accuracy:  0.844
# Test accuracy:  0.851
# Test accuracy:  0.844
# Test accuracy:  0.882
# Test accuracy:  0.846
# Test accuracy:  0.868
# Test accuracy:  0.859
# Test accuracy:  0.858
# Test accuracy:  0.851
# Test accuracy:  0.859
# Test accuracy:  0.864
# Test accuracy:  0.84
# Test accuracy:  0.867
# Test accuracy:  0.853
# Test accuracy:  0.842
# Test accuracy:  0.87
# Test accuracy:  0.856
# Test accuracy:  0.851
# Test accuracy:  0.866
# Test accuracy:  0.843
# Test accuracy:  0.844
# Test accuracy:  0.847
# Test accuracy:  0.852
# Test accuracy:  0.841
# 3350 83% (265m 11s) 0.0355 0.0308 gave dem til Skarerne. Og de spiste alle og bleve  / danish ✓
# Train accuracy: 0.9858
# Test accuracy:  0.84
# Test accuracy:  0.85
# Test accuracy:  0.837
# Test accuracy:  0.863
# Test accuracy:  0.853
# Test accuracy:  0.867
# Test accuracy:  0.84
# Test accuracy:  0.853
# Test accuracy:  0.876
# Test accuracy:  0.846
# Test accuracy:  0.839
# Test accuracy:  0.843
# Test accuracy:  0.855
# Test accuracy:  0.853
# Test accuracy:  0.867
# Test accuracy:  0.843
# Test accuracy:  0.884
# Test accuracy:  0.866
# Test accuracy:  0.852
# Test accuracy:  0.852
# Test accuracy:  0.856
# Test accuracy:  0.852
# Test accuracy:  0.87
# Test accuracy:  0.86
# Test accuracy:  0.86
# Test accuracy:  0.867
# Test accuracy:  0.85
# Test accuracy:  0.872
# Test accuracy:  0.876
# Test accuracy:  0.851
# Test accuracy:  0.844
# Test accuracy:  0.857
# Test accuracy:  0.852
# Test accuracy:  0.845
# Test accuracy:  0.869
# Test accuracy:  0.864
# Test accuracy:  0.848
# Test accuracy:  0.842
# Test accuracy:  0.849
# Test accuracy:  0.84
# Test accuracy:  0.859
# Test accuracy:  0.87
# Test accuracy:  0.885
# Test accuracy:  0.865
# Test accuracy:  0.868
# Test accuracy:  0.872
# Test accuracy:  0.873
# Test accuracy:  0.879
# Test accuracy:  0.859
# Test accuracy:  0.866
# 3400 85% (277m 13s) 0.0639 0.0415 ing; and the watchman called unto the porter, and  / english ✓
# Train accuracy: 0.9848
# Test accuracy:  0.869
# Test accuracy:  0.856
# Test accuracy:  0.864
# Test accuracy:  0.872
# Test accuracy:  0.869
# Test accuracy:  0.856
# Test accuracy:  0.866
# Test accuracy:  0.873
# Test accuracy:  0.859
# Test accuracy:  0.849
# Test accuracy:  0.874
# Test accuracy:  0.861
# Test accuracy:  0.858
# Test accuracy:  0.863
# Test accuracy:  0.862
# Test accuracy:  0.852
# Test accuracy:  0.862
# Test accuracy:  0.857
# Test accuracy:  0.856
# Test accuracy:  0.833
# Test accuracy:  0.852
# Test accuracy:  0.867
# Test accuracy:  0.861
# Test accuracy:  0.862
# Test accuracy:  0.867
# Test accuracy:  0.855
# Test accuracy:  0.861
# Test accuracy:  0.874
# Test accuracy:  0.861
# Test accuracy:  0.85
# Test accuracy:  0.873
# Test accuracy:  0.874
# Test accuracy:  0.85
# Test accuracy:  0.871
# Test accuracy:  0.875
# Test accuracy:  0.875
# Test accuracy:  0.864
# Test accuracy:  0.878
# Test accuracy:  0.871
# Test accuracy:  0.875
# Test accuracy:  0.88
# Test accuracy:  0.848
# Test accuracy:  0.873
# Test accuracy:  0.866
# Test accuracy:  0.862
# Test accuracy:  0.87
# Test accuracy:  0.859
# Test accuracy:  0.862
# Test accuracy:  0.873
# Test accuracy:  0.875
# 3450 86% (289m 20s) 0.0227 0.0199 i fjalen time! A nuk leron tere diten bujku per te / albanian ✓
# Train accuracy: 0.9812
# Test accuracy:  0.873
# Test accuracy:  0.854
# Test accuracy:  0.862
# Test accuracy:  0.876
# Test accuracy:  0.853
# Test accuracy:  0.862
# Test accuracy:  0.858
# Test accuracy:  0.865
# Test accuracy:  0.862
# Test accuracy:  0.849
# Test accuracy:  0.861
# Test accuracy:  0.861
# Test accuracy:  0.858
# Test accuracy:  0.854
# Test accuracy:  0.871
# Test accuracy:  0.844
# Test accuracy:  0.863
# Test accuracy:  0.869
# Test accuracy:  0.88
# Test accuracy:  0.854
# Test accuracy:  0.879
# Test accuracy:  0.882
# Test accuracy:  0.867
# Test accuracy:  0.872
# Test accuracy:  0.868
# Test accuracy:  0.859
# Test accuracy:  0.857
# Test accuracy:  0.879
# Test accuracy:  0.847
# Test accuracy:  0.878
# Test accuracy:  0.881
# Test accuracy:  0.862
# Test accuracy:  0.839
# Test accuracy:  0.857
# Test accuracy:  0.866
# Test accuracy:  0.881
# Test accuracy:  0.86
# Test accuracy:  0.865
# Test accuracy:  0.866
# Test accuracy:  0.868
# Test accuracy:  0.866
# Test accuracy:  0.892
# Test accuracy:  0.865
# Test accuracy:  0.852
# Test accuracy:  0.868
# Test accuracy:  0.878
# Test accuracy:  0.863
# Test accuracy:  0.899
# Test accuracy:  0.868
# Test accuracy:  0.867
# 3500 87% (303m 17s) 0.0658 0.0563 ,  andiyi kubeva. Wabiza ngelizwi elikhulu ezindle / xhosa ✓
# Train accuracy: 0.9834
# Test accuracy:  0.854
# Test accuracy:  0.879
# Test accuracy:  0.863
# Test accuracy:  0.84
# Test accuracy:  0.84
# Test accuracy:  0.857
# Test accuracy:  0.866
# Test accuracy:  0.853
# Test accuracy:  0.854
# Test accuracy:  0.862
# Test accuracy:  0.839
# Test accuracy:  0.857
# Test accuracy:  0.862
# Test accuracy:  0.854
# Test accuracy:  0.862
# Test accuracy:  0.888
# Test accuracy:  0.858
# Test accuracy:  0.866
# Test accuracy:  0.863
# Test accuracy:  0.866
# Test accuracy:  0.866
# Test accuracy:  0.858
# Test accuracy:  0.881
# Test accuracy:  0.878
# Test accuracy:  0.862
# Test accuracy:  0.873
# Test accuracy:  0.882
# Test accuracy:  0.851
# Test accuracy:  0.847
# Test accuracy:  0.839
# Test accuracy:  0.879
# Test accuracy:  0.864
# Test accuracy:  0.864
# Test accuracy:  0.87
# Test accuracy:  0.854
# Test accuracy:  0.87
# Test accuracy:  0.86
# Test accuracy:  0.867
# Test accuracy:  0.873
# Test accuracy:  0.864
# Test accuracy:  0.878
# Test accuracy:  0.885
# Test accuracy:  0.887
# Test accuracy:  0.866
# Test accuracy:  0.871
# Test accuracy:  0.853
# Test accuracy:  0.887
# Test accuracy:  0.875
# Test accuracy:  0.875
# Test accuracy:  0.859
# 3550 88% (315m 34s) 0.0276 0.0160 e la chose est arretee de Dieu, et que Dieu se hat / french ✓
# Train accuracy: 0.9872
# Test accuracy:  0.874
# Test accuracy:  0.872
# Test accuracy:  0.863
# Test accuracy:  0.868
# Test accuracy:  0.852
# Test accuracy:  0.862
# Test accuracy:  0.877
# Test accuracy:  0.866
# Test accuracy:  0.868
# Test accuracy:  0.873
# Test accuracy:  0.861
# Test accuracy:  0.855
# Test accuracy:  0.857
# Test accuracy:  0.886
# Test accuracy:  0.867
# Test accuracy:  0.858
# Test accuracy:  0.875
# Test accuracy:  0.868
# Test accuracy:  0.886
# Test accuracy:  0.867
# Test accuracy:  0.885
# Test accuracy:  0.845
# Test accuracy:  0.876
# Test accuracy:  0.875
# Test accuracy:  0.884
# Test accuracy:  0.884
# Test accuracy:  0.862
# Test accuracy:  0.858
# Test accuracy:  0.872
# Test accuracy:  0.876
# Test accuracy:  0.869
# Test accuracy:  0.876
# Test accuracy:  0.874
# Test accuracy:  0.871
# Test accuracy:  0.868
# Test accuracy:  0.864
# Test accuracy:  0.865
# Test accuracy:  0.858
# Test accuracy:  0.872
# Test accuracy:  0.88
# Test accuracy:  0.867
# Test accuracy:  0.891
# Test accuracy:  0.869
# Test accuracy:  0.862
# Test accuracy:  0.864
# Test accuracy:  0.875
# Test accuracy:  0.86
# Test accuracy:  0.863
# Test accuracy:  0.86
# Test accuracy:  0.847
# 3600 90% (328m 44s) 0.0297 0.0241 n her seyin bir sonu oldugunu gordum,<br />Ama sen / turkish ✓
# Train accuracy: 0.985
# Test accuracy:  0.871
# Test accuracy:  0.867
# Test accuracy:  0.874
# Test accuracy:  0.859
# Test accuracy:  0.88
# Test accuracy:  0.864
# Test accuracy:  0.86
# Test accuracy:  0.881
# Test accuracy:  0.868
# Test accuracy:  0.87
# Test accuracy:  0.851
# Test accuracy:  0.861
# Test accuracy:  0.881
# Test accuracy:  0.848
# Test accuracy:  0.871
# Test accuracy:  0.887
# Test accuracy:  0.86
# Test accuracy:  0.848
# Test accuracy:  0.85
# Test accuracy:  0.87
# Test accuracy:  0.866
# Test accuracy:  0.88
# Test accuracy:  0.885
# Test accuracy:  0.869
# Test accuracy:  0.845
# Test accuracy:  0.852
# Test accuracy:  0.87
# Test accuracy:  0.865
# Test accuracy:  0.851
# Test accuracy:  0.875
# Test accuracy:  0.845
# Test accuracy:  0.86
# Test accuracy:  0.88
# Test accuracy:  0.861
# Test accuracy:  0.842
# Test accuracy:  0.859
# Test accuracy:  0.872
# Test accuracy:  0.856
# Test accuracy:  0.86
# Test accuracy:  0.855
# Test accuracy:  0.855
# Test accuracy:  0.87
# Test accuracy:  0.859
# Test accuracy:  0.892
# Test accuracy:  0.864
# Test accuracy:  0.869
# Test accuracy:  0.857
# Test accuracy:  0.871
# Test accuracy:  0.856
# Test accuracy:  0.873
# 3650 91% (341m 59s) 0.0043 0.0039 ordulardan olusan buyuk bir topluluk belirdi. Tanr / turkish ✓
# Train accuracy: 0.9832
# Test accuracy:  0.876
# Test accuracy:  0.855
# Test accuracy:  0.866
# Test accuracy:  0.849
# Test accuracy:  0.881
# Test accuracy:  0.861
# Test accuracy:  0.852
# Test accuracy:  0.863
# Test accuracy:  0.853
# Test accuracy:  0.875
# Test accuracy:  0.872
# Test accuracy:  0.859
# Test accuracy:  0.857
# Test accuracy:  0.874
# Test accuracy:  0.878
# Test accuracy:  0.872
# Test accuracy:  0.856
# Test accuracy:  0.861
# Test accuracy:  0.872
# Test accuracy:  0.851
# Test accuracy:  0.877
# Test accuracy:  0.889
# Test accuracy:  0.876
# Test accuracy:  0.877
# Test accuracy:  0.87
# Test accuracy:  0.888
# Test accuracy:  0.869
# Test accuracy:  0.867
# Test accuracy:  0.869
# Test accuracy:  0.872
# Test accuracy:  0.86
# Test accuracy:  0.874
# Test accuracy:  0.844
# Test accuracy:  0.863
# Test accuracy:  0.872
# Test accuracy:  0.87
# Test accuracy:  0.871
# Test accuracy:  0.856
# Test accuracy:  0.869
# Test accuracy:  0.883
# Test accuracy:  0.869
# Test accuracy:  0.875
# Test accuracy:  0.874
# Test accuracy:  0.885
# Test accuracy:  0.881
# Test accuracy:  0.895
# Test accuracy:  0.866
# Test accuracy:  0.892
# Test accuracy:  0.867
# Test accuracy:  0.889
# 3700 92% (356m 9s) 0.0163 0.0122 ascha?" Jis atsake: "Eikite i miesta pas toki zmog / lithuanian ✓
# Train accuracy: 0.9852
# Test accuracy:  0.87
# Test accuracy:  0.869
# Test accuracy:  0.871
# Test accuracy:  0.858
# Test accuracy:  0.881
# Test accuracy:  0.869
# Test accuracy:  0.863
# Test accuracy:  0.868
# Test accuracy:  0.878
# Test accuracy:  0.875
# Test accuracy:  0.87
# Test accuracy:  0.858
# Test accuracy:  0.868
# Test accuracy:  0.871
# Test accuracy:  0.862
# Test accuracy:  0.863
# Test accuracy:  0.883
# Test accuracy:  0.884
# Test accuracy:  0.861
# Test accuracy:  0.861
# Test accuracy:  0.866
# Test accuracy:  0.879
# Test accuracy:  0.855
# Test accuracy:  0.857
# Test accuracy:  0.85
# Test accuracy:  0.867
# Test accuracy:  0.879
# Test accuracy:  0.851
# Test accuracy:  0.873
# Test accuracy:  0.878
# Test accuracy:  0.863
# Test accuracy:  0.862
# Test accuracy:  0.862
# Test accuracy:  0.875
# Test accuracy:  0.874
# Test accuracy:  0.869
# Test accuracy:  0.872
# Test accuracy:  0.876
# Test accuracy:  0.859
# Test accuracy:  0.881
# Test accuracy:  0.868
# Test accuracy:  0.866
# Test accuracy:  0.873
# Test accuracy:  0.884
# Test accuracy:  0.868
# Test accuracy:  0.865
# Test accuracy:  0.885
# Test accuracy:  0.872
# Test accuracy:  0.86
# Test accuracy:  0.876
# 3750 93% (368m 37s) 0.0753 0.0413  luftetaret qe kane vajtur te luftojne nje harac p / albanian ✓
# Train accuracy: 0.9872
# Test accuracy:  0.869
# Test accuracy:  0.867
# Test accuracy:  0.859
# Test accuracy:  0.869
# Test accuracy:  0.87
# Test accuracy:  0.871
# Test accuracy:  0.872
# Test accuracy:  0.869
# Test accuracy:  0.87
# Test accuracy:  0.865
# Test accuracy:  0.869
# Test accuracy:  0.878
# Test accuracy:  0.857
# Test accuracy:  0.861
# Test accuracy:  0.863
# Test accuracy:  0.862
# Test accuracy:  0.84
# Test accuracy:  0.863
# Test accuracy:  0.87
# Test accuracy:  0.858
# Test accuracy:  0.848
# Test accuracy:  0.861
# Test accuracy:  0.858
# Test accuracy:  0.849
# Test accuracy:  0.865
# Test accuracy:  0.879
# Test accuracy:  0.85
# Test accuracy:  0.885
# Test accuracy:  0.869
# Test accuracy:  0.851
# Test accuracy:  0.872
# Test accuracy:  0.878
# Test accuracy:  0.888
# Test accuracy:  0.856
# Test accuracy:  0.865
# Test accuracy:  0.872
# Test accuracy:  0.854
# Test accuracy:  0.873
# Test accuracy:  0.872
# Test accuracy:  0.869
# Test accuracy:  0.854
# Test accuracy:  0.87
# Test accuracy:  0.855
# Test accuracy:  0.867
# Test accuracy:  0.861
# Test accuracy:  0.867
# Test accuracy:  0.862
# Test accuracy:  0.838
# Test accuracy:  0.879
# Test accuracy:  0.854
# 3800 95% (381m 7s) 0.0515 0.0495 ho nguoi ta tuy viec ho lam: su thanh no cho ke do / vietnamese ✓
# Train accuracy: 0.9856
# Test accuracy:  0.858
# Test accuracy:  0.859
# Test accuracy:  0.86
# Test accuracy:  0.826
# Test accuracy:  0.874
# Test accuracy:  0.877
# Test accuracy:  0.876
# Test accuracy:  0.869
# Test accuracy:  0.851
# Test accuracy:  0.857
# Test accuracy:  0.866
# Test accuracy:  0.862
# Test accuracy:  0.886
# Test accuracy:  0.889
# Test accuracy:  0.854
# Test accuracy:  0.876
# Test accuracy:  0.866
# Test accuracy:  0.875
# Test accuracy:  0.87
# Test accuracy:  0.878
# Test accuracy:  0.869
# Test accuracy:  0.87
# Test accuracy:  0.871
# Test accuracy:  0.881
# Test accuracy:  0.86
# Test accuracy:  0.88
# Test accuracy:  0.875
# Test accuracy:  0.864
# Test accuracy:  0.847
# Test accuracy:  0.857
# Test accuracy:  0.872
# Test accuracy:  0.857
# Test accuracy:  0.866
# Test accuracy:  0.852
# Test accuracy:  0.861
# Test accuracy:  0.87
# Test accuracy:  0.877
# Test accuracy:  0.861
# Test accuracy:  0.876
# Test accuracy:  0.863
# Test accuracy:  0.842
# Test accuracy:  0.879
# Test accuracy:  0.854
# Test accuracy:  0.865
# Test accuracy:  0.867
# Test accuracy:  0.849
# Test accuracy:  0.862
# Test accuracy:  0.861
# Test accuracy:  0.857
# Test accuracy:  0.857
# 3850 96% (393m 27s) 0.0146 0.0130 giorno del primo mese. Il giorno dopo la Pasqua i  / italian ✓
# Train accuracy: 0.9886
# Test accuracy:  0.878
# Test accuracy:  0.867
# Test accuracy:  0.884
# Test accuracy:  0.884
# Test accuracy:  0.869
# Test accuracy:  0.882
# Test accuracy:  0.875
# Test accuracy:  0.86
# Test accuracy:  0.874
# Test accuracy:  0.876
# Test accuracy:  0.884
# Test accuracy:  0.877
# Test accuracy:  0.897
# Test accuracy:  0.886
# Test accuracy:  0.888
# Test accuracy:  0.848
# Test accuracy:  0.881
# Test accuracy:  0.885
# Test accuracy:  0.868
# Test accuracy:  0.885
# Test accuracy:  0.867
# Test accuracy:  0.879
# Test accuracy:  0.856
# Test accuracy:  0.871
# Test accuracy:  0.88
# Test accuracy:  0.878
# Test accuracy:  0.875
# Test accuracy:  0.869
# Test accuracy:  0.87
# Test accuracy:  0.864
# Test accuracy:  0.876
# Test accuracy:  0.88
# Test accuracy:  0.851
# Test accuracy:  0.863
# Test accuracy:  0.872
# Test accuracy:  0.859
# Test accuracy:  0.851
# Test accuracy:  0.865
# Test accuracy:  0.866
# Test accuracy:  0.874
# Test accuracy:  0.88
# Test accuracy:  0.865
# Test accuracy:  0.87
# Test accuracy:  0.875
# Test accuracy:  0.861
# Test accuracy:  0.85
# Test accuracy:  0.868
# Test accuracy:  0.859
# Test accuracy:  0.849
# Test accuracy:  0.859
# 3900 97% (406m 43s) 0.0144 0.0119 ivat heita enaa puhumasta tai opettamasta yhtaan m / finnish ✓
# Train accuracy: 0.9866
# Test accuracy:  0.883
# Test accuracy:  0.87
# Test accuracy:  0.865
# Test accuracy:  0.863
# Test accuracy:  0.87
# Test accuracy:  0.866
# Test accuracy:  0.856
# Test accuracy:  0.88
# Test accuracy:  0.856
# Test accuracy:  0.866
# Test accuracy:  0.865
# Test accuracy:  0.865
# Test accuracy:  0.881
# Test accuracy:  0.869
# Test accuracy:  0.869
# Test accuracy:  0.854
# Test accuracy:  0.858
# Test accuracy:  0.859
# Test accuracy:  0.88
# Test accuracy:  0.872
# Test accuracy:  0.873
# Test accuracy:  0.876
# Test accuracy:  0.883
# Test accuracy:  0.883
# Test accuracy:  0.861
# Test accuracy:  0.88
# Test accuracy:  0.869
# Test accuracy:  0.866
# Test accuracy:  0.854
# Test accuracy:  0.88
# Test accuracy:  0.867
# Test accuracy:  0.858
# Test accuracy:  0.863
# Test accuracy:  0.892
# Test accuracy:  0.866
# Test accuracy:  0.874
# Test accuracy:  0.876
# Test accuracy:  0.875
# Test accuracy:  0.887
# Test accuracy:  0.868
# Test accuracy:  0.869
# Test accuracy:  0.864
# Test accuracy:  0.868
# Test accuracy:  0.876
# Test accuracy:  0.868
# Test accuracy:  0.889
# Test accuracy:  0.868
# Test accuracy:  0.852
# Test accuracy:  0.83
# Test accuracy:  0.882
# 3950 98% (420m 11s) 0.1121 0.0705 esen, partieron. Y esperandolos Pablo en Atenas, s / spanish ✓
# Train accuracy: 0.9862
# Test accuracy:  0.865
# Test accuracy:  0.864
# Test accuracy:  0.863
# Test accuracy:  0.849
# Test accuracy:  0.876
# Test accuracy:  0.865
# Test accuracy:  0.858
# Test accuracy:  0.879
# Test accuracy:  0.861
# Test accuracy:  0.856
# Test accuracy:  0.856
# Test accuracy:  0.868
# Test accuracy:  0.846
# Test accuracy:  0.87
# Test accuracy:  0.868
# Test accuracy:  0.87
# Test accuracy:  0.876
# Test accuracy:  0.867
# Test accuracy:  0.855
# Test accuracy:  0.869
# Test accuracy:  0.861
# Test accuracy:  0.867
# Test accuracy:  0.871
# Test accuracy:  0.867
# Test accuracy:  0.871
# Test accuracy:  0.867
# Test accuracy:  0.879
# Test accuracy:  0.88
# Test accuracy:  0.872
# Test accuracy:  0.875
# Test accuracy:  0.884
# Test accuracy:  0.863
# Test accuracy:  0.876
# Test accuracy:  0.877
# Test accuracy:  0.882
# Test accuracy:  0.875
# Test accuracy:  0.881
# Test accuracy:  0.864
# Test accuracy:  0.894
# Test accuracy:  0.876
# Test accuracy:  0.879
# Test accuracy:  0.879
# Test accuracy:  0.873
# Test accuracy:  0.856
# Test accuracy:  0.886
# Test accuracy:  0.88
# Test accuracy:  0.86
# Test accuracy:  0.872
# Test accuracy:  0.873
# Test accuracy:  0.875
# 4000 100% (433m 58s) 0.0107 0.0098 du? Sie sagt zu ihm: Sprich, dass diese meine beid / german ✓
# Train accuracy: 0.9832
# Test accuracy:  0.875

# %% [markdown]
# Plot loss functions
# --------------------

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_losses, color='b')
plt.plot(all_test_losses, color='r')

# %% [markdown]
# Evaluate results
# -------------------
#
# We now vizualize the performance of our model by creating a confusion matrix. The ground truth languages of samples are represented by rows in the matrix while the predicted languages are represented by columns.
#
# In this evaluation we consider sequences of variable sizes rather than the fixed length sequences we used for training.

# %%
eval_batch_size = 1  # needs to be set to 1 for evaluating different sequence lengths

# Keep track of correct guesses in a confusion matrix
confusion = torch.zeros(n_languages, n_languages)
n_confusion = 1000
num_correct = 0
total = 0

for i in range(n_confusion):
    eval_chunk_len = random.randint(10, 50) # in evaluation we will look at sequences of variable sizes
    input_data, target_category, text_data = load_random_batch(test_category_data, chunk_len=eval_chunk_len, batch_size=eval_batch_size)
    output = evaluate(rnn, input_data, seq_len=eval_chunk_len, batch_size=eval_batch_size)
    
    guess_i = categoryFromOutput(output)
    category_i = [int(target_category[idx]) for idx in range(len(target_category))]
    for j in range(eval_batch_size):
        category = all_categories[category_i[j]] 
        confusion[category_i[j]][guess_i[j]] += 1
        num_correct += int(guess_i[j]==category_i[j])
        total += 1

print('Test accuracy: ', float(num_correct)/float(n_confusion*eval_batch_size))

# Normalize by dividing every row by its sum
for i in range(n_languages):
    confusion[i] = confusion[i] / confusion[i].sum()

# Set up plot
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(confusion.numpy())
fig.colorbar(cax)

# Set up axes
ax.set_xticklabels([''] + all_categories, rotation=90)
ax.set_yticklabels([''] + all_categories)

# Force label at every tick
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()
# Out:
# Test accuracy:  0.876

# %% [markdown]
# You can pick out bright spots off the main axis that show which
# languages it guesses incorrectly.

# %% [markdown]
# Run on User Input
# ---------------------
#
# Now you can test your model on your own input.

# %%
def predict(input_line, n_predictions=5):
    print('\n> %s' % input_line)
    with torch.no_grad():
        input_data = stringToTensor(input_line).long().unsqueeze(0).to(device)
        output = evaluate(rnn, input_data, seq_len=len(input_line), batch_size=1)

    # Get top N categories
    topv, topi = output.topk(n_predictions, dim=1)
    predictions = []

    for i in range(n_predictions):
        topv.shape
        topi.shape
        value = topv[0][i].item()
        category_index = topi[0][i].item()
        print('(%.2f) %s' % (value, all_categories[category_index]))
        predictions.append([value, all_categories[category_index]])

predict('This is a phrase to test the model on user input')
# Out:
# > This is a phrase to test the model on user input
# (11.55) english
# (3.41) vietnamese
# (3.29) spanish
# (2.60) xhosa
# (1.58) french

# %% [markdown]
# # Output Kaggle submission file
#
# Once you have found a good set of hyperparameters submit the output of your model on the Kaggle test file.

# %%
### DO NOT CHANGE KAGGLE SUBMISSION CODE ####
import csv

kaggle_test_file_path = 'language_data/kaggle_rnn_language_classification_test.txt'
with open(kaggle_test_file_path, 'r') as f:
    lines = f.readlines()

output_rows = []
for i, line in enumerate(lines):
    sample = line.rstrip()
    sample_chunk_len = len(sample)
    input_data = stringToTensor(sample).unsqueeze(0)
    output = evaluate(rnn, input_data, seq_len=sample_chunk_len, batch_size=1)
    guess_i = categoryFromOutput(output)
    output_rows.append((str(i+1), all_categories[guess_i]))

submission_file_path = 'kaggle_rnn_submission.txt'
with open(submission_file_path, 'w') as f:
    output_rows = [('id', 'category')] + output_rows
    writer = csv.writer(f)
    writer.writerows(output_rows)
