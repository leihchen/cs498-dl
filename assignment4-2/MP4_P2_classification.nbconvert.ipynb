# %%
import os
import time
import math
import glob
import string
import random 
# !conda install torch, torchvision
import torch
import torch.nn as nn
import csv
from rnn.helpers import time_since
# !conda install unidecode
# %matplotlib inline

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Language recognition with an RNN
#
# If you've ever used an online translator you've probably seen a feature that automatically detects the input language. While this might be easy to do if you input unicode characters that are unique to one or a small group of languages (like "你好" or "γεια σας"), this problem is more challenging if the input only uses the available ASCII characters. In this case, something like "těší mě" would beome "tesi me" in the ascii form. This is a more challenging problem in which the language must be recognized purely by the pattern of characters rather than unique unicode characters.
#
# We will train an RNN to solve this problem for a small set of languages thta can be converted to romanized ASCII form. For training data it would be ideal to have a large and varied dataset in different language styles. However, it is easy to find copies of the Bible which is a large text translated to different languages but in the same easily parsable format, so we will use 20 different copies of the Bible as training data. Using the same book for all of the different languages will hopefully prevent minor overfitting that might arise if we used different books for each language (fitting to common characteristics of the individual books rather than the language).

# %%
from unidecode import unidecode as unicodeToAscii

all_characters = string.printable
n_letters = len(all_characters)

print(unicodeToAscii('těší mě'))
# Out:
# tesi me

# %%
# Read a file and split into lines
def readFile(filename):
    data = open(filename, encoding='utf-8').read().strip()
    return unicodeToAscii(data)

def get_category_data(data_path):
    # Build the category_data dictionary, a list of names per language
    category_data = {}
    all_categories = []
    for filename in glob.glob(data_path):
        category = os.path.splitext(os.path.basename(filename))[0].split('_')[0]
        all_categories.append(category)
        data = readFile(filename)
        category_data[category] = data
    
    return category_data, all_categories

# %% [markdown]
# The original text is split into two parts, train and test, so that we can make sure that the model is not simply memorizing the train data.

# %%
train_data_path = 'language_data/train/*_train.txt'
test_data_path = 'language_data/test/*_test.txt'

train_category_data, all_categories = get_category_data(train_data_path)
test_category_data, test_all_categories = get_category_data(test_data_path)

n_languages = len(all_categories)

print(len(all_categories))
print(all_categories)
# Out:
# 20
# ['english', 'esperanto', 'albanian', 'finnish', 'spanish', 'italian', 'lithuanian', 'french', 'maori', 'romanian', 'german', 'portuguese', 'turkish', 'swedish', 'hungarian', 'czech', 'vietnamese', 'xhosa', 'danish', 'norwegian']

# %% [markdown]
# # Data processing

# %%
def categoryFromOutput(output):
    top_n, top_i = output.topk(1, dim=1)
    category_i = top_i[:, 0]
    return category_i

# Turn string into long tensor
def stringToTensor(string):
    tensor = torch.zeros(len(string), requires_grad=True).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return tensor

def load_random_batch(text, chunk_len, batch_size):
    input_data = torch.zeros(batch_size, chunk_len).long().to(device)
    target = torch.zeros(batch_size, 1).long().to(device)
    input_text = []
    for i in range(batch_size):
        category = all_categories[random.randint(0, len(all_categories) - 1)]
        line_start = random.randint(0, len(text[category])-chunk_len)
        category_tensor = torch.tensor([all_categories.index(category)], dtype=torch.long)
        line = text[category][line_start:line_start+chunk_len]
        input_text.append(line)
        input_data[i] = stringToTensor(line)
        target[i] = category_tensor
    return input_data, target, input_text

# %% [markdown]
# Implement Model
# ====================
#
# For this classification task, we can use the same model we implement for the generation task which is located in `rnn/model.py`. See the `MP4_P2_generation.ipynb` notebook for more instructions. In this case each output vector of our RNN will have the dimension of the number of possible languages (i.e. `n_languages`). We will use this vector to predict a distribution over the languages.
#
# In the generation task, we used the output of the RNN at every time step to predict the next letter and our loss included the output from each of these predictions. However, in this task we use the output of the RNN at the end of the sequence to predict the language, so our loss function will use only the predicted output from the last time step.

# %% [markdown]
# # Train RNN

# %%
from rnn.model import RNN

# %%
chunk_len = 50

BATCH_SIZE = 100
n_epochs = 10000
hidden_size = 160
n_layers = 3
learning_rate = 0.0001
model_type = 'lstm'

criterion = nn.CrossEntropyLoss()
rnn = RNN(n_letters, hidden_size, n_languages, model_type=model_type, n_layers=n_layers).to(device)

# %% [markdown]
# **TODO:** Fill in the train function. You should initialize a hidden layer representation using your RNN's `init_hidden` function, set the model gradients to zero, and loop over each time step (character) in the input tensor. For each time step compute the output of the of the RNN and the next hidden layer representation. The cross entropy loss should be computed over the last RNN output scores from the end of the sequence and the target classification tensor. Lastly, call backward on the loss and take an optimizer step.

# %%
def train(rnn, target_tensor, data_tensor, optimizer, criterion, batch_size=BATCH_SIZE):
    """
    Inputs:
    - rnn: model
    - target_target: target character data tensor of shape (batch_size, 1)
    - data_tensor: input character data tensor of shape (batch_size, chunk_len)
    - optimizer: rnn model optimizer
    - criterion: loss function
    - batch_size: data batch size
    
    Returns:
    - output: output from RNN from end of sequence 
    - loss: computed loss value as python float
    
    """
    
    output, loss = None, None
    
    ####################################
    #          YOUR CODE HERE          #
    ####################################
    hidden = rnn.init_hidden(data_tensor.shape[0])
    rnn.zero_grad()
    for i in range(chunk_len):
        output, hidden = rnn(data_tensor[:, i], hidden)
    loss = criterion(output.reshape(batch_size, -1), target_tensor.squeeze())
    loss.backward()
    optimizer.step()
    
    ##########       END      ##########

    return output, loss

# %%
def evaluate(rnn, data_tensor, seq_len=chunk_len, batch_size=BATCH_SIZE):
    with torch.no_grad():
        data_tensor = data_tensor.to(device)
        hidden = rnn.init_hidden(batch_size, device=device)
        for i in range(seq_len):
            output, hidden = rnn(data_tensor[:,i], hidden)
        
        return output
    
def eval_test(rnn, category_tensor, data_tensor):
    with torch.no_grad():
        output = evaluate(rnn, data_tensor)
        loss = criterion(output, category_tensor.squeeze())
        return output, loss.item()

# %%
n_iters = 100000
print_every = 50
plot_every = 50


# Keep track of losses for plotting
current_loss = 0
current_test_loss = 0
all_losses = []
all_test_losses = []

start = time.time()

optimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate)


number_correct = 0
for iter in range(1, n_iters + 1):
    input_data, target_category, text_data = load_random_batch(train_category_data, chunk_len, BATCH_SIZE)
    output, loss = train(rnn, target_category, input_data, optimizer, criterion)
    current_loss += loss
    
    _, test_loss = eval_test(rnn, target_category, input_data)
    current_test_loss += test_loss
    
    guess_i = categoryFromOutput(output)
    number_correct += (target_category.squeeze()==guess_i.squeeze()).long().sum()
    
    # Print iter number, loss, name and guess
    if iter % print_every == 0:
        sample_idx = 0
        guess = all_categories[guess_i[sample_idx]]
        
        category = all_categories[int(target_category[sample_idx])]
        
        correct = '✓' if guess == category else '✗ (%s)' % category
        print('%d %d%% (%s) %.4f %.4f %s / %s %s' % (iter, iter / n_iters * 100, time_since(start), loss, test_loss, text_data[sample_idx], guess, correct))
        print('Train accuracy: {}'.format(float(number_correct)/float(print_every*BATCH_SIZE)))
        number_correct = 0
    
    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0
        all_test_losses.append(current_test_loss / plot_every)
        current_test_loss = 0
    if iter % (print_every*5) == 0:
        eval_batch_size = 1  # needs to be set to 1 for evaluating different sequence lengths

        # Keep track of correct guesses in a confusion matrix
        confusion = torch.zeros(n_languages, n_languages)
        n_confusion = 1000
        num_correct = 0
        total = 0

        for i in range(n_confusion):
            eval_chunk_len = random.randint(10, 50) # in evaluation we will look at sequences of variable sizes
            input_data, target_category, text_data = load_random_batch(test_category_data, chunk_len=eval_chunk_len, batch_size=eval_batch_size)
            output = evaluate(rnn, input_data, seq_len=eval_chunk_len, batch_size=eval_batch_size)

            guess_i = categoryFromOutput(output)
            category_i = [int(target_category[idx]) for idx in range(len(target_category))]
            for j in range(eval_batch_size):
                category = all_categories[category_i[j]] 
                confusion[category_i[j]][guess_i[j]] += 1
                num_correct += int(guess_i[j]==category_i[j])
                total += 1

        print('Test accuracy: ', float(num_correct)/float(n_confusion*eval_batch_size))
        if float(num_correct)/float(n_confusion*eval_batch_size) > .89 or iter == 250:
            torch.save(rnn.state_dict(), './rnn_classifier'+str(iter)+'.pth')
            kaggle_test_file_path = 'language_data/kaggle_rnn_language_classification_test.txt'
            with open(kaggle_test_file_path, 'r') as f:
                lines = f.readlines()

            output_rows = []
            for i, line in enumerate(lines):
                sample = line.rstrip()
                sample_chunk_len = len(sample)
                input_data = stringToTensor(sample).unsqueeze(0)
                output = evaluate(rnn, input_data, seq_len=sample_chunk_len, batch_size=1)
                guess_i = categoryFromOutput(output)
                output_rows.append((str(i+1), all_categories[guess_i]))

            submission_file_path = 'kaggle_rnn_submission'+str(iter)+'.txt'
            with open(submission_file_path, 'w') as f:
                output_rows = [('id', 'category')] + output_rows
                writer = csv.writer(f)
                writer.writerows(output_rows)
# Out:
# 50 0% (0m 11s) 2.9873 2.9867  Toate zilele noastre pier de urgia Ta, vedem cum  / english ✗ (romanian)
# Train accuracy: 0.062
# 100 0% (0m 22s) 2.7476 2.7288 eggi, io non ti mandero addosso alcuna delle malat / danish ✗ (italian)
# Train accuracy: 0.1198
# 150 0% (0m 34s) 2.2919 2.2916 pe cineva fara voie, fara sa aiba vreun gind sa -l / maori ✗ (romanian)
# Train accuracy: 0.197
# 200 0% (0m 45s) 1.7817 1.7340 kaae mai ai aua tangata ki a tatou, kia noho ki a  / maori ✓
# Train accuracy: 0.3492
# 250 0% (0m 56s) 1.5798 1.5526  hoki i te whare katoa o tona papa: kaua hoki e ko / maori ✓
# Train accuracy: 0.4512
# Test accuracy:  0.39
# 4400 4% (22m 2s) 0.2794 0.2095  atnesdavo kudikiu, kad Jis juos paliestu. Mokinia / lithuanian ✓
# Train accuracy: 0.9368
# 4450 4% (22m 13s) 0.0887 0.0823 er darkness: there shall be the weeping and the gn / english ✓
# Train accuracy: 0.9292
# 4500 4% (22m 25s) 0.1730 0.1621 darbus, susijusius su Susitikimo palapine, priziur / lithuanian ✓
# Train accuracy: 0.943
# Test accuracy:  0.758
# 4550 4% (22m 51s) 0.2277 0.1904 para ti, cuando dije: Yo he convidado al pueblo. Y / spanish ✓
# Train accuracy: 0.9308
# 4600 4% (23m 3s) 0.1019 0.0946 te paret e shtepive aterore te Ladanit, Gershoniti / albanian ✓
# Train accuracy: 0.9332
# 4650 4% (23m 14s) 0.1213 0.1142 defeito diante do Senhor; pora a mao sobre a cabec / portuguese ✓
# Train accuracy: 0.9406
# 4700 4% (23m 26s) 0.1899 0.1887 maellel, Natanianak fiaval, es elerek ot a nagy vi / hungarian ✓
# Train accuracy: 0.939
# 4750 4% (23m 37s) 0.2236 0.2106 uf und handle und verziehe nicht, um deiner selbst / german ✓
# Train accuracy: 0.9314
# Test accuracy:  0.748
# 4800 4% (24m 2s) 0.3136 0.2978 isse a Samuele: "Fino a quando farai tu cordoglio  / italian ✓
# Train accuracy: 0.9454
# 4850 4% (24m 13s) 0.1268 0.1246 mer der to Gange Nod. Er de end som sammenflettet  / norwegian ✗ (danish)
# Train accuracy: 0.938
# 4900 4% (24m 24s) 0.2301 0.1830 m, mondvan: Menj el, es kialts Jeruzsalem fuleibe, / hungarian ✓
# Train accuracy: 0.9442
# 4950 4% (24m 36s) 0.1163 0.1065 itokban; mert valaki kovaszost ejendik, az a lelek / hungarian ✓
# Train accuracy: 0.9382
# 5000 5% (24m 47s) 0.1556 0.1434 ju kuno akmenine sirdi ir duosiu jiems kuno sirdi. / lithuanian ✓
# Train accuracy: 0.941
# Test accuracy:  0.764
# 5050 5% (25m 12s) 0.1489 0.1439 ltar, afara de altarul Domnului, Dumnezeului nostr / romanian ✓
# Train accuracy: 0.9508
# 5100 5% (25m 24s) 0.1325 0.1106 aroha nei? Pahemo kau atu ratou, kua tutaki ahau k / maori ✓
# Train accuracy: 0.947
# 5150 5% (25m 36s) 0.2103 0.1952 ches der HERR dem Sohn meines Herrn bestimmt hat!  / german ✓
# Train accuracy: 0.9402
# 5200 5% (25m 47s) 0.1400 0.1291 sti srdce. Nazyvaji me tvym jmenem, Hospodine, Boz / czech ✓
# Train accuracy: 0.949
# 5250 5% (25m 59s) 0.1808 0.1735  som ferdes i overmot, makter han a ydmyke. Kong B / norwegian ✓
# Train accuracy: 0.9458
# Test accuracy:  0.755
# 5300 5% (26m 22s) 0.1204 0.0997 si Perasiminvuoren luona, niin kuin kiivastui Gibe / finnish ✓
# Train accuracy: 0.9442
# 5350 5% (26m 33s) 0.1244 0.1160 pururea in casa; fiul insa ramine pururea. Deci, d / romanian ✓
# Train accuracy: 0.9466
# 5400 5% (26m 45s) 0.1081 0.1033  stora dag ar nara, ja, den ar nara, den kommer me / swedish ✓
# Train accuracy: 0.9446
# 5450 5% (26m 56s) 0.1540 0.1405 den rige Mand engang fik Besog, ommede han sig ved / danish ✓
# Train accuracy: 0.941
# 5500 5% (27m 8s) 0.1288 0.1162 iuvo, sandeliai tusti, klojimai nenaudojami, nes j / lithuanian ✓
# Train accuracy: 0.9436
# Test accuracy:  0.742
# 5550 5% (27m 31s) 0.1244 0.1131 m ke nao bi cung khon, ke nao mac no, va nhung ngu / vietnamese ✓
# Train accuracy: 0.9432
# 5600 5% (27m 43s) 0.1273 0.1058 alcun uomo per coltivare il suolo; ma un vapore sa / italian ✓
# Train accuracy: 0.9468
# 5650 5% (27m 54s) 0.2718 0.2320 j Gezeron. (Faraono, regxo de Egiptujo, venis kaj  / esperanto ✓
# Train accuracy: 0.9534
# 5700 5% (28m 6s) 0.1343 0.1108 ek s megis veled vagyok. Vajha elvesztene Isten a  / hungarian ✓
# Train accuracy: 0.9478
# 5750 5% (28m 17s) 0.0975 0.0897 adassek, hogy ha valaki harmincz napig ker valamit / hungarian ✓
# Train accuracy: 0.9452
# Test accuracy:  0.764
# 5800 5% (28m 41s) 0.2071 0.1778 tanas, Jehojados sunus Benajas, keretai ir peletai / lithuanian ✓
# Train accuracy: 0.954
# 5850 5% (28m 52s) 0.1571 0.1570 Davide andava diventando sempre piu grande, e l'Et / portuguese ✗ (italian)
# Train accuracy: 0.9486
# 5900 5% (29m 3s) 0.0824 0.0813 ina para a direita, mas o coracao do tolo o inclin / portuguese ✓
# Train accuracy: 0.9528
# 5950 5% (29m 15s) 0.1660 0.1477 e, vaer drukne uden Vin og rav uden Drik! Thi HERR / danish ✓
# Train accuracy: 0.9518
# 6000 6% (29m 26s) 0.1264 0.1231 a uDavide watsho kakhulu. Wathi uYonatan kuDavide, / xhosa ✓
# Train accuracy: 0.9512
# Test accuracy:  0.755
# 6050 6% (29m 49s) 0.1036 0.1013 ignita; egli perdona l'iniquita e il peccato, ma n / italian ✓
# Train accuracy: 0.9518
# 6100 6% (30m 1s) 0.2221 0.1852  efter dem og helliget dem; han stod tidlig op om  / norwegian ✓
# Train accuracy: 0.9566
# 6150 6% (30m 12s) 0.1547 0.1386 ele ngamathambo. Wandidlulisa kuwo, wandijikelezis / xhosa ✓
# Train accuracy: 0.9492
# 6200 6% (30m 23s) 0.1686 0.1478 ka mori rrobat me te bukura te Esaut, birit te saj / albanian ✓
# Train accuracy: 0.95
# 6250 6% (30m 35s) 0.0706 0.0672 vocato il mio nome, per contaminarla. Hanno edific / italian ✓
# Train accuracy: 0.9574
# Test accuracy:  0.777
# 6300 6% (30m 59s) 0.0951 0.0803 sias>> (det betyder detsamma som Kristus). Och han / swedish ✓
# Train accuracy: 0.9564
# 6350 6% (31m 11s) 0.1634 0.1283 tim-fabol; hossza egy sing, szelessege is egy sing / hungarian ✓
# Train accuracy: 0.9536
# 6400 6% (31m 22s) 0.0880 0.0861 ize. Ekubeni mna ndibathanda, bona bayandichasa, N / xhosa ✓
# Train accuracy: 0.9552
# 6450 6% (31m 33s) 0.1186 0.0847 vos: paga ao culpado, fazendo recair sobre a sua c / portuguese ✓
# Train accuracy: 0.955
# 6500 6% (31m 44s) 0.0926 0.0937  gjore i Herrens frykt, med troskap og med udelt h / norwegian ✓
# Train accuracy: 0.9546
# Test accuracy:  0.788
# 6550 6% (32m 7s) 0.1085 0.0957 a Saul gick hem till Gibea; och honom foljde en ha / swedish ✓
# Train accuracy: 0.9572
# 6600 6% (32m 18s) 0.0645 0.0595 uceligim icin ustun gucumle kralligimin baskenti o / turkish ✓
# Train accuracy: 0.959
# 6650 6% (32m 29s) 0.2725 0.2548 n loytanyt viisauden, se, joka on tavoittanut tied / finnish ✓
# Train accuracy: 0.9648
# 6700 6% (32m 38s) 0.0779 0.0454 iul lui Iabes, a uneltit impotriva lui, l -a lovit / romanian ✓
# Train accuracy: 0.9588
# 6750 6% (32m 46s) 0.1774 0.1466 mme sine Born. Abner jeg et Moderliv og hindrer de / danish ✓
# Train accuracy: 0.9548
# Test accuracy:  0.79
# 6800 6% (33m 10s) 0.1030 0.0869 ide. Igama lonina belinguNahama, umAmonikazi. UAbh / xhosa ✓
# Train accuracy: 0.9536
# 6850 6% (33m 22s) 0.1692 0.1194 y za sebe a za svuj dum vykonal smirci obrady, a p / czech ✓
# Train accuracy: 0.9562
# 6900 6% (33m 33s) 0.1635 0.1358 pe vreo citiva din capii lui Israel. Ioram avea tr / romanian ✓
# Train accuracy: 0.9592
# 6950 6% (33m 44s) 0.0645 0.0616  la suerte, delante de Aman, de dia en dia y de me / spanish ✓
# Train accuracy: 0.9618
# 7000 7% (33m 55s) 0.0906 0.0837 prit etait aussi repandu sur les Gentils; Car ils  / french ✓
# Train accuracy: 0.9598
# Test accuracy:  0.802
# 7050 7% (34m 19s) 0.1149 0.0925 it: Ne dois-je pas prendre garde de dire ce que l' / french ✓
# Train accuracy: 0.9624
# 7100 7% (34m 30s) 0.1920 0.1678 over hela Israels hus. Sa sager Herren, HERREN: De / danish ✗ (swedish)
# Train accuracy: 0.9556
# 7150 7% (34m 41s) 0.1050 0.0903 re menn fra Jerusalem, som var innbudt, og som gik / norwegian ✓
# Train accuracy: 0.9598
# 7200 7% (34m 53s) 0.0522 0.0518  a nuestro amo, y el los ha zaherido. Mas aquellos / spanish ✓
# Train accuracy: 0.958
# 7250 7% (35m 4s) 0.1742 0.1577 ndlwini kaYehova,  benamacangci, nemirhubhe, neeha / xhosa ✓
# Train accuracy: 0.9658
# Test accuracy:  0.79
# 7300 7% (35m 28s) 0.0773 0.0599  discxiploj kaj granda homamaso, la filo de Timeo, / esperanto ✓
# Train accuracy: 0.9604
# 7350 7% (35m 39s) 0.1905 0.1757 eluya! Dumisani, bakhonzi bakaYehova, Dumisani iga / xhosa ✓
# Train accuracy: 0.9618
# 7400 7% (35m 50s) 0.0686 0.0395 ay trong vuon Duc Chua Troi deu ganh go no. Vay ne / vietnamese ✓
# Train accuracy: 0.9588
# 7450 7% (36m 1s) 0.1186 0.1105 f men shall fall as dung upon the open field, and  / english ✓
# Train accuracy: 0.9636
# 7500 7% (36m 13s) 0.1131 0.0898  fuerza: Libre entre los muertos, Como los matados / spanish ✓
# Train accuracy: 0.9624
# Test accuracy:  0.798
# 7550 7% (36m 36s) 0.1162 0.1092 de velat saga till honom: >>Kop vad vi behova till / swedish ✓
# Train accuracy: 0.9636
# 7600 7% (36m 47s) 0.0617 0.0595 ta e patua ai tenei Pirihitini, e mutu ai te tawai / maori ✓
# Train accuracy: 0.9582
# 7650 7% (36m 58s) 0.1148 0.1051 lu judskych. Kdyz proti nemu v Jeruzaleme zosnoval / czech ✓
# Train accuracy: 0.9582
# 7700 7% (37m 10s) 0.0983 0.0802 primogenito, e i suoi figliuoli. Dei figliuoli di  / italian ✓
# Train accuracy: 0.9652
# 7750 7% (37m 21s) 0.1291 0.1209 e Levi quatro mil e seiscentos; Jeoiada, que era o / spanish ✗ (portuguese)
# Train accuracy: 0.9682
# Test accuracy:  0.808
# 7800 7% (37m 44s) 0.0898 0.0562 na seison vartiopaikallani, asetun tahystamaan saa / finnish ✓
# Train accuracy: 0.966
# 7850 7% (37m 56s) 0.1059 0.0972 skal sorge for a overgi ham i kongens hand. Saul s / norwegian ✓
# Train accuracy: 0.9606
# 7900 7% (38m 7s) 0.1334 0.1190 ei a mim. Isto dizia, significando de que modo hav / portuguese ✓
# Train accuracy: 0.9574
# 7950 7% (38m 18s) 0.0776 0.0742  tyre plasi murtaja. Por Finehasi u ngrit dhe beri / albanian ✓
# Train accuracy: 0.9664
# 8000 8% (38m 29s) 0.0610 0.0492 lla guerra per schiere, composte secondo il numero / italian ✓
# Train accuracy: 0.964
# Test accuracy:  0.781
# 8050 8% (38m 52s) 0.0967 0.0792 lyder det fra Haerskarers HERRE. Dette Hus's komme / danish ✓
# Train accuracy: 0.965
# 8100 8% (39m 4s) 0.1238 0.1079 ietai ir jos gyventojams' ". Jie visa tai pranese  / lithuanian ✓
# Train accuracy: 0.9662
# 8150 8% (39m 15s) 0.0971 0.0852 c, deu den tham va an bua voi nguoi tai trong nha  / vietnamese ✓
# Train accuracy: 0.966
# 8200 8% (39m 26s) 0.1015 0.0880 mittaisivat meidat taalta pois? Ei, tulkoot itse p / finnish ✓
# Train accuracy: 0.959
# 8250 8% (39m 37s) 0.0669 0.0404 er that speaketh in you. And brother shall deliver / english ✓
# Train accuracy: 0.9654
# Test accuracy:  0.805
# 8300 8% (40m 1s) 0.0938 0.0844 ti slouzit sedm let za tvou mladsi dceru Rachel."  / czech ✓
# Train accuracy: 0.9618
# 8350 8% (40m 13s) 0.0568 0.0530 lorosa chaga. Se eu saio ao campo, eis os mortos   / portuguese ✓
# Train accuracy: 0.9696
# 8400 8% (40m 25s) 0.1031 0.0907  Mattanyayi kral yapti ve adini degistirip Sidkiya / turkish ✓
# Train accuracy: 0.9654
# 8450 8% (40m 36s) 0.0617 0.0519 lvera, y enojarase contra el pacto santo, y hara:  / spanish ✓
# Train accuracy: 0.9836
# 15650 15% (69m 31s) 0.0178 0.0174 araone s'era sdegnato contro i suoi servitori, e m / italian ✓
# Train accuracy: 0.9856
# 15700 15% (69m 37s) 0.0563 0.0386 unnitelman seka suunnitelman huoneesta, jossa liit / finnish ✓
# Train accuracy: 0.9816
# 15750 15% (69m 43s) 0.0965 0.0738 at, medan han levde. Och hans broder och hela hans / swedish ✓
# Train accuracy: 0.9794
# Test accuracy:  0.839
# 15800 15% (70m 2s) 0.0757 0.0704 i.`` El este acela care, in adunarea Israelitilor  / romanian ✓
# Train accuracy: 0.9786
# 15850 15% (70m 8s) 0.1526 0.1319  Abel-Beth-Maaca, Janoach, Kedes, Hatsor, Galaad,  / danish ✗ (french)
# Train accuracy: 0.9842
# 15900 15% (70m 18s) 0.0378 0.0366  to him, Behold, thou art but a dead man, because  / english ✓
# Train accuracy: 0.9784
# 15950 15% (70m 29s) 0.0845 0.0604 raqiti bijve te Izraelit. Keto jane regullat, stat / albanian ✓
# Train accuracy: 0.981
# 16000 16% (70m 40s) 0.0661 0.0655 he sword. Then Jezebel send a messenger unto Elija / english ✓
# Train accuracy: 0.9814
# Test accuracy:  0.862
# 16050 16% (71m 4s) 0.0272 0.0226 etoret, sherbetoret, te rinjte tuaj me te mire dhe / albanian ✓
# Train accuracy: 0.9848
# 16100 16% (71m 15s) 0.0569 0.0511 giler sunun Tanriya, ezgiler;<br />Ezgiler sunun K / turkish ✓
# Train accuracy: 0.9808
# 16150 16% (71m 26s) 0.0657 0.0643 a; po, po ju them, nga ai te keni frike. A nuk shi / albanian ✓
# Train accuracy: 0.9852
# 16200 16% (71m 37s) 0.0771 0.0593 gitt levittene til arv; derfor har jeg sagt til de / norwegian ✓
# Train accuracy: 0.98
# 16250 16% (71m 49s) 0.1072 0.1000 sta calea, si nu este aceasta cetatea; veniti dupa / romanian ✓
# Train accuracy: 0.977
# Test accuracy:  0.867
# 16300 16% (72m 12s) 0.0184 0.0179 strengthened the bars of thy gates; He hath blesse / english ✓
# Train accuracy: 0.9804
# 16350 16% (72m 23s) 0.0313 0.0147  ovumelana nathi ngale ndawo yodwa amadoda lawo,   / xhosa ✓
# Train accuracy: 0.9864
# 16400 16% (72m 35s) 0.0272 0.0224 lo Hitteo. Allora Joab invio un messo a Davide per / spanish ✗ (italian)
# Train accuracy: 0.9848
# 16450 16% (72m 46s) 0.0734 0.0719 anga, akusivikivanga, akuthabathanga nto sandleni  / xhosa ✓
# Train accuracy: 0.9806
# 16500 16% (72m 57s) 0.0380 0.0329 er. And thou shalt make loops of blue upon the edg / english ✓
# Train accuracy: 0.9854
# Test accuracy:  0.854
# 16550 16% (73m 20s) 0.0373 0.0321 athi, xenikweni iYerusalem ibithinjiwe (ngomnyaka  / xhosa ✓
# Train accuracy: 0.9822
# 16600 16% (73m 32s) 0.0152 0.0141 tetahi hawhe ki tetahi. Na ko te kianga atu a te w / maori ✓
# Train accuracy: 0.9826
# 18700 18% (82m 57s) 0.0278 0.0226 nga hoki, i mea mai, E ora ana ano ranei to koutou / maori ✓
# Train accuracy: 0.9838
# 18750 18% (83m 8s) 0.0212 0.0167 tando, pois, os filhos de Israel entre os cananeus / portuguese ✓
# Train accuracy: 0.9832
# Test accuracy:  0.859
# 18800 18% (83m 32s) 0.0435 0.0411 te a voi stessi, che talora i vostri cuori non sia / italian ✓
# Train accuracy: 0.9842
# 18850 18% (83m 43s) 0.0730 0.0669 p, foll omkull och blev liggande; ja, vid hennes f / swedish ✓
# Train accuracy: 0.9806
# 18900 18% (83m 54s) 0.0770 0.0627 ro famiglie: da Thola discende la famiglia dei Tho / italian ✓
# Train accuracy: 0.9852
# 18950 18% (84m 5s) 0.0556 0.0519 eshi ta mbarte arken e Zotit prane vetes se tij ne / albanian ✓
# Train accuracy: 0.9834
# 19000 19% (84m 17s) 0.0369 0.0361 s hijo de Joachaz sobre Israel en Samaria; y reino / spanish ✓
# Train accuracy: 0.9858
# Test accuracy:  0.859
# 19050 19% (84m 40s) 0.0515 0.0427 ms, and the fat of fed beasts; and I delight not i / english ✓
# Train accuracy: 0.9826
# 19100 19% (84m 51s) 0.0309 0.0209 s alas como aguilas, correran, y no se cansaran, c / spanish ✓
# Train accuracy: 0.9842
# 19150 19% (85m 3s) 0.1063 0.0557 n ubergehen und wider uns kampfen und aus dem Land / german ✓
# Train accuracy: 0.9852
# 19200 19% (85m 14s) 0.0093 0.0086 n puo liberare alcuno col suo grande vigore. Ecco, / italian ✓
# Train accuracy: 0.9828
# 19250 19% (85m 25s) 0.1148 0.0837 ndler sa ryggeslost, at I laver eder Gudebilleder  / danish ✓
# Train accuracy: 0.9886
# Test accuracy:  0.882
# 19300 19% (85m 48s) 0.0114 0.0107 dres. De la Roca que te crio te olvidaste: Te has  / spanish ✓
# Train accuracy: 0.9844
# 19350 19% (86m 0s) 0.0786 0.0581  gli disse: "Va' con cotesta tua forza, e salva Is / italian ✓
# Train accuracy: 0.9842
# 19400 19% (86m 11s) 0.0905 0.0783 t; chung no bi nguoi dat Gat giet, vi co xuong Gat / vietnamese ✓
# Train accuracy: 0.9862
# ...
# Train accuracy: 0.9958
# 93700 93% (655m 5s) 0.0024 0.0022 es of the Levites, out of the half-tribe of Manass / english ✓
# Train accuracy: 0.9962
# 93750 93% (655m 16s) 0.0649 0.0532 ntill barnbarn, nar man haller hans forbund och ta / swedish ✓
# Train accuracy: 0.9954
# Test accuracy:  0.918
# 93800 93% (656m 38s) 0.0015 0.0013 Dio faru la nomon de Salomono pli fama, ol via nom / esperanto ✓
# Train accuracy: 0.9964
# 93850 93% (656m 49s) 0.0049 0.0042 ra. Nato mi Hospodin rekl: "Hod to tavicovi, tu na / czech ✓
# Train accuracy: 0.9962
# 93900 93% (657m 0s) 0.0017 0.0016 plankeme?' Ir atsakys jiems Karalius: 'Is tiesu sa / lithuanian ✓
# Train accuracy: 0.997
# 93950 93% (657m 11s) 0.0003 0.0003 ato una donna!" Il suo giovane allora lo trafisse, / italian ✓
# Train accuracy: 0.9972
# 94000 94% (657m 22s) 0.0035 0.0025  may nguoi duoc chuc giu do khi dung, vi cac do ay / vietnamese ✓
# Train accuracy: 0.9988
# Test accuracy:  0.92
# 94050 94% (658m 44s) 0.0146 0.0096 y even that which he hath. And he said, So is the  / english ✓
# Train accuracy: 0.997
# 94100 94% (658m 55s) 0.0068 0.0057  e gojes sime dhe mos u largo prej tyre; mos e bra / albanian ✓
# Train accuracy: 0.9956
# 94150 94% (659m 6s) 0.0013 0.0014 e urdherimet e tua. O Zot, toka eshte e mbushur me / albanian ✓
# Train accuracy: 0.9968
# 94200 94% (659m 17s) 0.0016 0.0015 j, sin jxetante antaux lin, sciigis antaux la tuta / esperanto ✓
# Train accuracy: 0.996
# 94250 94% (659m 29s) 0.0065 0.0053  Tiun, kiu min sendis. Mi venis lumo en la mondon, / esperanto ✓
# Train accuracy: 0.998
# Test accuracy:  0.929
# 94300 94% (660m 51s) 0.0006 0.0006  Quivi ha spezzato le saette dell'arco, lo scudo,  / italian ✓
# Train accuracy: 0.9956
# 94350 94% (661m 2s) 0.0040 0.0038 e, Vande stiger fra Nord, de bliver en Strom, der  / danish ✓
# Train accuracy: 0.996
# 94400 94% (661m 14s) 0.0014 0.0012 ouverts de honte. Hymne de David, qu'il chanta a l / french ✓
# Train accuracy: 0.9978
# 94450 94% (661m 25s) 0.0005 0.0005 eigoje atrisome maisus ir kiekvieno musu visi pini / lithuanian ✓
# Train accuracy: 0.9978
# 94500 94% (661m 36s) 0.0033 0.0029  ne zemerim dhe pushtetmadh, por nuk e le pa e nde / albanian ✓
# Train accuracy: 0.9986
# Test accuracy:  0.935
# 94550 94% (662m 58s) 0.0052 0.0050 nes Skyld ikke afvise hende: Og Kongen sendte stra / danish ✓
# Train accuracy: 0.9972
# 94600 94% (663m 9s) 0.0785 0.0681 errama de tristeza por causa do quebrantamento da  / portuguese ✓
# Train accuracy: 0.9968
# 94650 94% (663m 20s) 0.0011 0.0010 gamashumi omane anesihlanu amawaka, anamakhulu mat / xhosa ✓
# Train accuracy: 0.9982
# 94700 94% (663m 31s) 0.0002 0.0002 e beni cagirsalar bile onlari dinlemeyecegim.>> So / turkish ✓
# Train accuracy: 0.9972
# 94750 94% (663m 43s) 0.0009 0.0009 e do te ule krenarine e tij bashke me trillimet e  / albanian ✓
# Train accuracy: 0.9972
# Test accuracy:  0.938
# 94800 94% (665m 4s) 0.0014 0.0013 zat es tomjen, hogy aldozzanak az Ur hazaban. Es k / hungarian ✓
# Train accuracy: 0.9958
# 94850 94% (665m 16s) 0.0009 0.0007  se porte bien; il vit encore. Et ils s'inclineren / french ✓
# Train accuracy: 0.997
# 94900 94% (665m 27s) 0.0008 0.0008 is ilin al li,  por ke li timu Min, kaj li timis M / esperanto ✓
# Train accuracy: 0.9966
# 94950 94% (665m 38s) 0.0052 0.0032 rsehen hatten. Und sie hatten sich einzutragen sam / german ✓
# Train accuracy: 0.9962
# 95000 95% (665m 49s) 0.0011 0.0011  "Bekuar qofte Zoti, qe ju cliroi nga dora e Egjip / albanian ✓
# Train accuracy: 0.995
# Test accuracy:  0.928
# 95050 95% (667m 11s) 0.0006 0.0006 sipirko is Sichemo tevo Hamoro sunu uz simta monet / lithuanian ✓
# Train accuracy: 0.9974
# 95100 95% (667m 22s) 0.0662 0.0493 n de tritaga irado inter si kaj Jakob. Kaj Jakob p / esperanto ✓
# Train accuracy: 0.9972
# 95150 95% (667m 33s) 0.0087 0.0077 Elo phupha ndilibonile, mna kumkani Nebhukadenetsa / xhosa ✓
# Train accuracy: 0.9972
# 95200 95% (667m 44s) 0.0175 0.0142 RAB Leanin sevilmedigini gorunce, cocuk sahibi olm / turkish ✓
# Train accuracy: 0.9964
# 95250 95% (667m 55s) 0.0066 0.0063 rint, s feljegyeztetett az egesz suly abban az ido / hungarian ✓
# Train accuracy: 0.996
# Test accuracy:  0.909
# 95300 95% (669m 17s) 0.0056 0.0050 ttamaan Mordokain kaskyn mukaisesti juutalaisille  / finnish ✓
# Train accuracy: 0.9954
# 95350 95% (669m 28s) 0.0002 0.0002  mea he hohonu iho i te kiri ki tana titiro; a he  / maori ✓
# Train accuracy: 0.9974
# 95400 95% (669m 39s) 0.0038 0.0037 a bakaManase, bathetha neentloko zamawaka akwaSira / xhosa ✓
# Train accuracy: 0.9964
# 95450 95% (669m 50s) 0.0023 0.0023  ce lieu, et ils me tueront a cause de ma femme. M / french ✓
# Train accuracy: 0.9986
# 95500 95% (670m 2s) 0.0166 0.0048 r de o mandar a Jerusalem, armando ciladas para o  / portuguese ✓
# Train accuracy: 0.998
# Test accuracy:  0.908
# 95550 95% (671m 24s) 0.0461 0.0368  Toto pravi Hospodin: "Neucte se ceste pronarodu a / czech ✓
# Train accuracy: 0.9976
# 95600 95% (671m 35s) 0.0169 0.0085  ahora? Y Josue les respondio: Si eres pueblo tan  / spanish ✓
# Train accuracy: 0.9952
# 95650 95% (671m 46s) 0.0005 0.0005  odasina gizledi. Cocugu Atalyadan gizleyerek kurt / turkish ✓
# Train accuracy: 0.9966
# 95700 95% (671m 57s) 0.0085 0.0073 hung qua song Gio-danh tai truoc mat vua. Chiec do / vietnamese ✓
# Train accuracy: 0.9972
# 95750 95% (672m 8s) 0.0114 0.0079 e nel soggiorno de' morti non ne risalira; non tor / italian ✓
# Train accuracy: 0.996
# Test accuracy:  0.937
# 95800 95% (673m 30s) 0.0124 0.0104 a Israelitterne sa, at Abimelek var dod, begav de  / danish ✓
# Train accuracy: 0.9976
# 95850 95% (673m 41s) 0.0138 0.0083 om ved Nattetide og omringede Byen. Naeste Morgen  / danish ✓
# Train accuracy: 0.9968
# 95900 95% (673m 52s) 0.0005 0.0006 bi, kuba izizwe zoonyana bakaSirayeli ziya kunamat / xhosa ✓
# Train accuracy: 0.9948
# 95950 95% (674m 2s) 0.0062 0.0051 i bathe bavumelana emhlabeni apha ngeendawo zonke  / xhosa ✓
# Train accuracy: 0.9974
# 96000 96% (674m 13s) 0.0004 0.0004  de cedro, pedreiros e carpinteiros para lhe edifi / portuguese ✓
# Train accuracy: 0.998
# Test accuracy:  0.931
# 96050 96% (675m 35s) 0.0002 0.0002  Na, ko tetahi tohunga e haere noa ana i taua ara: / maori ✓
# Train accuracy: 0.9992
# 96100 96% (675m 46s) 0.0104 0.0079 h gate: and he measured the south gate according t / english ✓
# Train accuracy: 0.9976
# 96150 96% (675m 57s) 0.0012 0.0010 llait te tij Esau; dhe e bekoi. Dhe tha: "A je ti  / albanian ✓
# Train accuracy: 0.9974
# 96200 96% (676m 9s) 0.0006 0.0006 lomon su hijo. Porque desde el tiempo de David y d / spanish ✓
# Train accuracy: 0.9968
# 96250 96% (676m 20s) 0.0029 0.0025  noras padaryti sandora su Viespaciu, Izraelio Die / lithuanian ✓
# Train accuracy: 0.9962
# Test accuracy:  0.939
# 96300 96% (677m 42s) 0.0008 0.0007 en spann vagnshastar och tolv tusen ridhastar. Och / swedish ✓
# Train accuracy: 0.997
# 96350 96% (677m 53s) 0.0198 0.0008 os meus ossos. Assim partiram de Sucote, e acampar / portuguese ✓
# Train accuracy: 0.9974
# 96400 96% (678m 4s) 0.0338 0.0267 , isakymus, paliepimus ir istatymus, kuriuos Jis t / lithuanian ✓
# Train accuracy: 0.9956
# 96450 96% (678m 16s) 0.0129 0.0123 cny podil, je vyrok Panovnika Hospodina." Toto jso / czech ✓
# Train accuracy: 0.9964
# 96500 96% (678m 27s) 0.0024 0.0024 a e ahau te pukapuka o te ture i te whare o Ihowa. / maori ✓
# Train accuracy: 0.9968
# Test accuracy:  0.939
# 96550 96% (679m 49s) 0.0127 0.0121 wahine kairau, a kua hokona e ratou he kotiro ki t / maori ✓
# Train accuracy: 0.9978
# 96600 96% (680m 0s) 0.0121 0.0042 auferstehen. Und er redete das Wort ganz unverhohl / german ✓
# Train accuracy: 0.9972
# 96650 96% (680m 12s) 0.0035 0.0034 cendre, et tu reuniras chez toi, dans la maison, t / french ✓
# Train accuracy: 0.9974
# 96700 96% (680m 23s) 0.0016 0.0016 hovah God, and what is my house, that thou hast br / english ✓
# Train accuracy: 0.9964
# 96750 96% (680m 34s) 0.0069 0.0037 o di quelli che cercano la loro vita; e Nebucadnet / italian ✓
# Train accuracy: 0.9968
# Test accuracy:  0.913
# 96800 96% (681m 56s) 0.0091 0.0075 conte burimet e humneres, kur i caktonte detit caq / albanian ✓
# Train accuracy: 0.9984
# 96850 96% (682m 7s) 0.0011 0.0011  que era conhecido do sumo sacerdote, falou  porte / portuguese ✓
# Train accuracy: 0.9978
# 96900 96% (682m 18s) 0.0487 0.0230 pasijuokia is zirgo ir raitelio. Ar tu suteikei zi / lithuanian ✓
# Train accuracy: 0.997
# 96950 96% (682m 30s) 0.0365 0.0273 as han icke hogeligen over din seger! Vad hans hja / swedish ✓
# Train accuracy: 0.9968
# 97000 97% (682m 41s) 0.0029 0.0030 ssi au-dessus de sa tete la cause de sa condamnati / french ✓
# Train accuracy: 0.9974
# Test accuracy:  0.936
# 97050 97% (684m 3s) 0.0003 0.0003 goan ma den: Trong viec xet doan tu vi nguoi, ay c / vietnamese ✓
# Train accuracy: 0.9954
# 97100 97% (684m 14s) 0.0091 0.0048 gxis blankaj kaj la infektajxo aspektas pli profun / esperanto ✓
# Train accuracy: 0.9948
# 97150 97% (684m 25s) 0.0021 0.0019 dneho smrti. Je to podobny pripad, jako kdyz nekdo / czech ✓
# Train accuracy: 0.996
# 97200 97% (684m 36s) 0.0012 0.0013  tillfriskna fran denna sjukdom. Sa gick da Hasael / swedish ✓
# Train accuracy: 0.9972
# 97250 97% (684m 48s) 0.0029 0.0028  Antiokhiaba. Es miutan [ott] bizonyos idot eltolt / hungarian ✓
# Train accuracy: 0.9968
# Test accuracy:  0.932
# 97300 97% (686m 10s) 0.0006 0.0006 n z nich pytel, aby dal svemu oslu obrok, uvidel s / czech ✓
# Train accuracy: 0.9976
# 97350 97% (686m 21s) 0.0164 0.0110 va upeliai, nes jie nesilaiko Tavo istatymo. Viesp / lithuanian ✓
# Train accuracy: 0.9976
# 97400 97% (686m 33s) 0.0042 0.0027 ssero state fatte le opere potenti compiute fra vo / italian ✓
# Train accuracy: 0.9972
# 97450 97% (686m 44s) 0.0284 0.0182 la regxo respondis:Nenio estas farita al li. La re / esperanto ✓
# Train accuracy: 0.9966
# 97500 97% (686m 55s) 0.0016 0.0011 ne pa deres Hoved. Sa sagde jeg: Saledes har de ho / danish ✓
# Train accuracy: 0.9966
# Test accuracy:  0.913
# 97550 97% (688m 18s) 0.0158 0.0141 y tears run down. Sigh, but not aloud, make no mou / english ✓
# Train accuracy: 0.9962
# 97600 97% (688m 29s) 0.0008 0.0008  asi sere ahora siervo tuyo, entonces tu me disipa / spanish ✓
# Train accuracy: 0.9968
# 97650 97% (688m 40s) 0.0004 0.0004 abato deginamoji auka, priedas prie kasdieniniu de / lithuanian ✓
# Train accuracy: 0.9974
# 97700 97% (688m 51s) 0.0035 0.0033 an sa hadde levd tusen ar to ganger, men ikke nytt / norwegian ✓
# Train accuracy: 0.9978
# 97750 97% (689m 3s) 0.0016 0.0016 enidoj, kaj Ramot en Gilead por la Gadidoj, kaj Go / esperanto ✓
# Train accuracy: 0.9966
# Test accuracy:  0.921
# 97800 97% (690m 25s) 0.0065 0.0042 do sveho rodiste; ja budu s tebou." Jakob si proto / czech ✓
# Train accuracy: 0.9976
# 97850 97% (690m 36s) 0.0016 0.0014 un er din Faster. Din Sonnekones Blusel ma du ikke / danish ✓
# Train accuracy: 0.9982
# 97900 97% (690m 47s) 0.0019 0.0008  virkaproj, kvin jaragxaj sxafidoj. Tio estis la o / esperanto ✓
# Train accuracy: 0.996
# 97950 97% (690m 59s) 0.0001 0.0001  nepaliauk del jo sauksmo. Kas greitas pykti, susi / lithuanian ✓
# Train accuracy: 0.9982
# 98000 98% (691m 10s) 0.0007 0.0006  o vento, e fez-se grande bonanca. Entao lhes perg / portuguese ✓
# Train accuracy: 0.997
# Test accuracy:  0.911
# Train accuracy: 0.9972
# 99100 99% (701m 8s) 0.0013 0.0009 ta sfatul meu: scoala-te, fugi la fratele meu Laba / romanian ✓
# Train accuracy: 0.9978
# 99150 99% (701m 19s) 0.0003 0.0003 Rabbin yolunu hazirlayin,  Gececegi patikalari duz / turkish ✓
# Train accuracy: 0.9958
# 99200 99% (701m 30s) 0.0007 0.0007  ylipapit ja fariseukset lahtivat yhdessa Pilatuks / finnish ✓
# Train accuracy: 0.9974
# 99250 99% (701m 41s) 0.0063 0.0030 scia andare il mio popolo, perche mi serva. Se tu  / italian ✓
# Train accuracy: 0.998
# Test accuracy:  0.932
# 99300 99% (703m 3s) 0.0057 0.0046 e nella strada, c'e un leone per le vie!" Come la  / italian ✓
# Train accuracy: 0.9958
# 99350 99% (703m 14s) 0.0384 0.0196  side av sjoen, til Kapernaum. Og det var allerede / norwegian ✓
# Train accuracy: 0.9976
# 99400 99% (703m 25s) 0.0006 0.0006 mi, dedicne ti patri vsechny pronarody! Pisen. Zal / czech ✓
# Train accuracy: 0.9972
# 99450 99% (703m 37s) 0.0012 0.0013 nicht ubermocht; auf meinem Rucken haben Pfluger g / german ✓
# Train accuracy: 0.9964
# 99500 99% (703m 48s) 0.0003 0.0003  cent vingt-cinq; Les enfants de Jerico, trois cen / french ✓
# Train accuracy: 0.9958
# Test accuracy:  0.93
# 99550 99% (705m 10s) 0.0410 0.0365 petuo a motivo della ribellione; e il corno getto  / italian ✓
# Train accuracy: 0.9954
# 99600 99% (705m 21s) 0.0001 0.0001 thine ear to my understanding: That thou mayest pr / english ✓
# Train accuracy: 0.9966
# 99650 99% (705m 32s) 0.0072 0.0060  oburu hafif iki turlu tarti olmayacak. Evinizde b / turkish ✓
# Train accuracy: 0.9978
# 99700 99% (705m 43s) 0.0017 0.0017 ja. A vidam elme jo orvossagul szolgal; a szomoru  / hungarian ✓
# Train accuracy: 0.9974
# 99750 99% (705m 55s) 0.0014 0.0013  de su sombra: seran vivificados como trigo, y flo / spanish ✓
# Train accuracy: 0.9972
# Test accuracy:  0.929
# 99800 99% (707m 16s) 0.0016 0.0013 cung thac, de Na-o-mi o lai, khong chong khong con / vietnamese ✓
# Train accuracy: 0.9958
# 99850 99% (707m 27s) 0.0013 0.0010 tau ki te wa e haere mai ai te rangatira o te whar / maori ✓
# Train accuracy: 0.9986
# 99900 99% (707m 39s) 0.0009 0.0009 tshatshazi, aboyalwa ngawo ngemini yento eyinqambi / xhosa ✓
# Train accuracy: 0.9964
# 99950 99% (707m 50s) 0.0007 0.0007 p my people [as] they eat bread, And call not upon / english ✓
# Train accuracy: 0.998
# 100000 100% (708m 1s) 0.0006 0.0006 ina dustu.>> Musa soyle yanitladi: <<Bu soyledikle / turkish ✓
# Train accuracy: 0.9974
# Test accuracy:  0.913

# %% [markdown]
# Plot loss functions
# --------------------

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_losses, color='b')
plt.plot(all_test_losses, color='r')

# %% [markdown]
# Evaluate results
# -------------------
#
# We now vizualize the performance of our model by creating a confusion matrix. The ground truth languages of samples are represented by rows in the matrix while the predicted languages are represented by columns.
#
# In this evaluation we consider sequences of variable sizes rather than the fixed length sequences we used for training.

# %%
eval_batch_size = 1  # needs to be set to 1 for evaluating different sequence lengths

# Keep track of correct guesses in a confusion matrix
confusion = torch.zeros(n_languages, n_languages)
n_confusion = 1000
num_correct = 0
total = 0

for i in range(n_confusion):
    eval_chunk_len = random.randint(10, 50) # in evaluation we will look at sequences of variable sizes
    input_data, target_category, text_data = load_random_batch(test_category_data, chunk_len=eval_chunk_len, batch_size=eval_batch_size)
    output = evaluate(rnn, input_data, seq_len=eval_chunk_len, batch_size=eval_batch_size)
    
    guess_i = categoryFromOutput(output)
    category_i = [int(target_category[idx]) for idx in range(len(target_category))]
    for j in range(eval_batch_size):
        category = all_categories[category_i[j]] 
        confusion[category_i[j]][guess_i[j]] += 1
        num_correct += int(guess_i[j]==category_i[j])
        total += 1

print('Test accuracy: ', float(num_correct)/float(n_confusion*eval_batch_size))

# Normalize by dividing every row by its sum
for i in range(n_languages):
    confusion[i] = confusion[i] / confusion[i].sum()

# Set up plot
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(confusion.numpy())
fig.colorbar(cax)

# Set up axes
ax.set_xticklabels([''] + all_categories, rotation=90)
ax.set_yticklabels([''] + all_categories)

# Force label at every tick
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()
# Out:
# Test accuracy:  0.928

# %% [markdown]
# You can pick out bright spots off the main axis that show which
# languages it guesses incorrectly.

# %% [markdown]
# Run on User Input
# ---------------------
#
# Now you can test your model on your own input.

# %%
def predict(input_line, n_predictions=5):
    print('\n> %s' % input_line)
    with torch.no_grad():
        input_data = stringToTensor(input_line).long().unsqueeze(0).to(device)
        output = evaluate(rnn, input_data, seq_len=len(input_line), batch_size=1)

    # Get top N categories
    topv, topi = output.topk(n_predictions, dim=1)
    predictions = []

    for i in range(n_predictions):
        topv.shape
        topi.shape
        value = topv[0][i].item()
        category_index = topi[0][i].item()
        print('(%.2f) %s' % (value, all_categories[category_index]))
        predictions.append([value, all_categories[category_index]])

predict('This is a phrase to test the model on user input')
# Out:
# > This is a phrase to test the model on user input
# (14.20) english
# (2.62) albanian
# (2.38) spanish
# (1.72) french
# (1.72) german

# %% [markdown]
# # Output Kaggle submission file
#
# Once you have found a good set of hyperparameters submit the output of your model on the Kaggle test file.

# %%
### DO NOT CHANGE KAGGLE SUBMISSION CODE ####
import csv

kaggle_test_file_path = 'language_data/kaggle_rnn_language_classification_test.txt'
with open(kaggle_test_file_path, 'r') as f:
    lines = f.readlines()

output_rows = []
for i, line in enumerate(lines):
    sample = line.rstrip()
    sample_chunk_len = len(sample)
    input_data = stringToTensor(sample).unsqueeze(0)
    output = evaluate(rnn, input_data, seq_len=sample_chunk_len, batch_size=1)
    guess_i = categoryFromOutput(output)
    output_rows.append((str(i+1), all_categories[guess_i]))

submission_file_path = 'kaggle_rnn_submission.txt'
with open(submission_file_path, 'w') as f:
    output_rows = [('id', 'category')] + output_rows
    writer = csv.writer(f)
    writer.writerows(output_rows)
