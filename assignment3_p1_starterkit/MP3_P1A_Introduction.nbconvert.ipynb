# %% [markdown]
# # Assignment 3 Part 1A Introduction: Multi-label Image Classification

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Multi-label Classification
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.
#
# ## Part 1A
# You will use this notebook to warm up with pytorch and the code+dataset that we will use for assignment3.
#
# ### What to do
# In part 1A, You are asked to run below experiments. You don't need to change hyperparameters for this Part 1A's experiments. (the following code provides everything that you will need.)
# 1. to train a simple network (defined in ```classifiers.py```)
# 2. to train the AlexNet (PyTorch built-in)
#     - from scratch
#     - finetuning AlexNet pretrained on ImageNet
#
#
#
# ### What to submit
# We ask you to run the following code and report the results in your homework submission. You may want to leverage this part 1A get yourself familiar with PyTorch.
#
# You will the need the numbers and plots this notebook outputs for reports, but you are not required to submit this notebook as a printed pdf.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('VOCdevkit_2007/VOC2007/', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))

# %% [markdown]
# # Classification

# %%
# declare what device to use: gpu/cpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
# plot functions
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Training the network
#
# The simple network you are given as is will allow you to reach around 0.15-0.2 mAP. In this project, you will find ways to design a better network. Save plots and final test mAP scores as you will be adding these to the writeup.

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
classifier = SimpleClassifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
# Training the Classifier
num_epochs = 20
test_frequency = 5

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 1 is 0.5030440092086792
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([10, 16, 26, 26])
# -------  Class: aeroplane        AP:   0.0773  -------
# -------  Class: bicycle          AP:   0.0453  -------
# -------  Class: bird             AP:   0.1137  -------
# -------  Class: boat             AP:   0.0772  -------
# -------  Class: bottle           AP:   0.0466  -------
# -------  Class: bus              AP:   0.0282  -------
# -------  Class: car              AP:   0.1101  -------
# -------  Class: cat              AP:   0.0994  -------
# -------  Class: chair            AP:   0.1286  -------
# -------  Class: cow              AP:   0.0308  -------
# -------  Class: diningtable      AP:   0.0566  -------
# -------  Class: dog              AP:   0.1292  -------
# -------  Class: horse            AP:   0.0499  -------
# -------  Class: motorbike        AP:   0.0430  -------
# -------  Class: person           AP:   0.3590  -------
# -------  Class: pottedplant      AP:   0.0472  -------
# -------  Class: sheep            AP:   0.0260  -------
# -------  Class: sofa             AP:   0.1028  -------
# -------  Class: train            AP:   0.0353  -------
# -------  Class: tvmonitor        AP:   0.0528  -------
# mAP: 0.0829
# Avg loss: 0.2536947128235125
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.0829439074629907
# Starting epoch number 2
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 2 is 0.2450663298368454
# Starting epoch number 3
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 3 is 0.24142120778560638
# Starting epoch number 4
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 4 is 0.24204808473587036
# Starting epoch number 5
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 5 is 0.2393810898065567
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([10, 16, 26, 26])
# -------  Class: aeroplane        AP:   0.0854  -------
# -------  Class: bicycle          AP:   0.0415  -------
# -------  Class: bird             AP:   0.1123  -------
# -------  Class: boat             AP:   0.0807  -------
# -------  Class: bottle           AP:   0.0508  -------
# -------  Class: bus              AP:   0.0295  -------
# -------  Class: car              AP:   0.1285  -------
# -------  Class: cat              AP:   0.1058  -------
# -------  Class: chair            AP:   0.1417  -------
# -------  Class: cow              AP:   0.0322  -------
# -------  Class: diningtable      AP:   0.0638  -------
# -------  Class: dog              AP:   0.1341  -------
# -------  Class: horse            AP:   0.0496  -------
# -------  Class: motorbike        AP:   0.0409  -------
# -------  Class: person           AP:   0.4861  -------
# -------  Class: pottedplant      AP:   0.0458  -------
# -------  Class: sheep            AP:   0.0278  -------
# -------  Class: sofa             AP:   0.1123  -------
# -------  Class: train            AP:   0.0365  -------
# -------  Class: tvmonitor        AP:   0.0564  -------
# mAP: 0.0931
# Avg loss: 0.2363253259191326
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.09307506554295313
# Starting epoch number 6
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 6 is 0.23877398669719696
# Starting epoch number 7
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 7 is 0.2380938082933426
# Starting epoch number 8
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 8 is 0.235152006149292
# Starting epoch number 9
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 9 is 0.23335301876068115
# Starting epoch number 10
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 10 is 0.23348356783390045
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([10, 16, 26, 26])
# -------  Class: aeroplane        AP:   0.2756  -------
# -------  Class: bicycle          AP:   0.0449  -------
# -------  Class: bird             AP:   0.1237  -------
# -------  Class: boat             AP:   0.1486  -------
# -------  Class: bottle           AP:   0.0694  -------
# -------  Class: bus              AP:   0.0625  -------
# -------  Class: car              AP:   0.1742  -------
# -------  Class: cat              AP:   0.1268  -------
# -------  Class: chair            AP:   0.1754  -------
# -------  Class: cow              AP:   0.0385  -------
# -------  Class: diningtable      AP:   0.0943  -------
# -------  Class: dog              AP:   0.1410  -------
# -------  Class: horse            AP:   0.0568  -------
# -------  Class: motorbike        AP:   0.0426  -------
# -------  Class: person           AP:   0.4809  -------
# -------  Class: pottedplant      AP:   0.0449  -------
# -------  Class: sheep            AP:   0.0336  -------
# -------  Class: sofa             AP:   0.1521  -------
# -------  Class: train            AP:   0.0742  -------
# -------  Class: tvmonitor        AP:   0.0651  -------
# mAP: 0.1213
# Avg loss: 0.22958543399969736
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.12125397070757915
# Starting epoch number 11
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 11 is 0.22765515744686127
# Starting epoch number 12
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 12 is 0.2279108166694641
# Starting epoch number 13
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 13 is 0.22693324089050293
# Starting epoch number 14
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 14 is 0.22516165673732758
# Starting epoch number 15
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 15 is 0.2241721749305725
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([10, 16, 26, 26])
# -------  Class: aeroplane        AP:   0.3475  -------
# -------  Class: bicycle          AP:   0.0607  -------
# -------  Class: bird             AP:   0.1062  -------
# -------  Class: boat             AP:   0.2101  -------
# -------  Class: bottle           AP:   0.0770  -------
# -------  Class: bus              AP:   0.0777  -------
# -------  Class: car              AP:   0.1960  -------
# -------  Class: cat              AP:   0.1433  -------
# -------  Class: chair            AP:   0.2101  -------
# -------  Class: cow              AP:   0.0440  -------
# -------  Class: diningtable      AP:   0.1179  -------
# -------  Class: dog              AP:   0.1541  -------
# -------  Class: horse            AP:   0.0775  -------
# -------  Class: motorbike        AP:   0.0485  -------
# -------  Class: person           AP:   0.4898  -------
# -------  Class: pottedplant      AP:   0.0533  -------
# -------  Class: sheep            AP:   0.0382  -------
# -------  Class: sofa             AP:   0.1610  -------
# -------  Class: train            AP:   0.1162  -------
# -------  Class: tvmonitor        AP:   0.0940  -------
# mAP: 0.1411
# Avg loss: 0.2241392655699861
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.14114820506898024
# Starting epoch number 16
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 16 is 0.22511060535907745
# Starting epoch number 17
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 17 is 0.2247282713651657
# Starting epoch number 18
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 18 is 0.22071073949337006
# Starting epoch number 19
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 19 is 0.218123197555542
# Starting epoch number 20
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# Loss for Training on Epoch 20 is 0.21871796250343323
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([1, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([10, 16, 26, 26])
# -------  Class: aeroplane        AP:   0.3454  -------
# -------  Class: bicycle          AP:   0.0708  -------
# -------  Class: bird             AP:   0.1049  -------
# -------  Class: boat             AP:   0.2515  -------
# -------  Class: bottle           AP:   0.0768  -------
# -------  Class: bus              AP:   0.0674  -------
# -------  Class: car              AP:   0.2401  -------
# -------  Class: cat              AP:   0.1360  -------
# -------  Class: chair            AP:   0.2220  -------
# -------  Class: cow              AP:   0.0524  -------
# -------  Class: diningtable      AP:   0.1391  -------
# -------  Class: dog              AP:   0.1522  -------
# -------  Class: horse            AP:   0.1119  -------
# -------  Class: motorbike        AP:   0.0579  -------
# -------  Class: person           AP:   0.4972  -------
# -------  Class: pottedplant      AP:   0.0645  -------
# -------  Class: sheep            AP:   0.0432  -------
# -------  Class: sofa             AP:   0.1627  -------
# -------  Class: train            AP:   0.1302  -------
# -------  Class: tvmonitor        AP:   0.1162  -------
# mAP: 0.1521
# Avg loss: 0.22256309787432352
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.15212195334934378

# %%
# Compare train and validation metrics
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_simple_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
# Out:
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([50, 16, 26, 26])
# torch.Size([2, 16, 26, 26])
# -------  Class: aeroplane        AP:   0.3173  -------
# -------  Class: bicycle          AP:   0.0633  -------
# -------  Class: bird             AP:   0.1061  -------
# -------  Class: boat             AP:   0.2014  -------
# -------  Class: bottle           AP:   0.0720  -------
# -------  Class: bus              AP:   0.0557  -------
# -------  Class: car              AP:   0.2749  -------
# -------  Class: cat              AP:   0.1293  -------
# -------  Class: chair            AP:   0.2209  -------
# -------  Class: cow              AP:   0.0625  -------
# -------  Class: diningtable      AP:   0.1017  -------
# -------  Class: dog              AP:   0.1614  -------
# -------  Class: horse            AP:   0.1078  -------
# -------  Class: motorbike        AP:   0.0675  -------
# -------  Class: person           AP:   0.5149  -------
# -------  Class: pottedplant      AP:   0.0599  -------
# -------  Class: sheep            AP:   0.0685  -------
# -------  Class: sofa             AP:   0.1648  -------
# -------  Class: train            AP:   0.1421  -------
# -------  Class: tvmonitor        AP:   0.1080  -------
# mAP: 0.1500
# Avg loss: 0.21903224796056747

# %%
output_submission_csv('my_solution.csv', test_aps)

# %% [markdown]
# # AlexNet Baselines (From Scratch)

# %% [markdown]
# AlexNet was one of the earliest deep learning models to have success in classification. In this section we will be running classification with AlexNet as a baseline. Furthermore, we will run an ImageNet-pretrained AlexNet to observe the impact of well-trained features. Save plots and final test mAP scores as you will be adding these to the writeup.

# %% [markdown]
# ## Running AlexNet
#
# In this section, we train AlexNet from scratch using the same hyperparameters as our previous experiment.

# %%
num_epochs = 20
test_frequency = 5

# Change classifier to AlexNet
classifier = torchvision.models.alexnet(pretrained=False)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)

criterion = nn.MultiLabelSoftMarginLoss()

optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.28501376509666443
# -------  Class: aeroplane        AP:   0.1172  -------
# -------  Class: bicycle          AP:   0.0457  -------
# -------  Class: bird             AP:   0.1108  -------
# -------  Class: boat             AP:   0.1137  -------
# -------  Class: bottle           AP:   0.0393  -------
# -------  Class: bus              AP:   0.0288  -------
# -------  Class: car              AP:   0.1086  -------
# -------  Class: cat              AP:   0.0962  -------
# -------  Class: chair            AP:   0.1136  -------
# -------  Class: cow              AP:   0.0350  -------
# -------  Class: diningtable      AP:   0.0493  -------
# -------  Class: dog              AP:   0.1175  -------
# -------  Class: horse            AP:   0.0474  -------
# -------  Class: motorbike        AP:   0.0364  -------
# -------  Class: person           AP:   0.3398  -------
# -------  Class: pottedplant      AP:   0.0437  -------
# -------  Class: sheep            AP:   0.0367  -------
# -------  Class: sofa             AP:   0.0911  -------
# -------  Class: train            AP:   0.0392  -------
# -------  Class: tvmonitor        AP:   0.0477  -------
# mAP: 0.0829
# Avg loss: 0.2411848964060054
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08288573912474007
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.24301372468471527
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23706234991550446
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.22943080961704254
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.22172826528549194
# -------  Class: aeroplane        AP:   0.3360  -------
# -------  Class: bicycle          AP:   0.0476  -------
# -------  Class: bird             AP:   0.0982  -------
# -------  Class: boat             AP:   0.2086  -------
# -------  Class: bottle           AP:   0.0809  -------
# -------  Class: bus              AP:   0.0405  -------
# -------  Class: car              AP:   0.2197  -------
# -------  Class: cat              AP:   0.1640  -------
# -------  Class: chair            AP:   0.2154  -------
# -------  Class: cow              AP:   0.0488  -------
# -------  Class: diningtable      AP:   0.1216  -------
# -------  Class: dog              AP:   0.1583  -------
# -------  Class: horse            AP:   0.0648  -------
# -------  Class: motorbike        AP:   0.0422  -------
# -------  Class: person           AP:   0.4983  -------
# -------  Class: pottedplant      AP:   0.0638  -------
# -------  Class: sheep            AP:   0.0370  -------
# -------  Class: sofa             AP:   0.1653  -------
# -------  Class: train            AP:   0.0962  -------
# -------  Class: tvmonitor        AP:   0.0691  -------
# mAP: 0.1388
# Avg loss: 0.24353367995982075
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.13881881296811138
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.2200460582971573
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.2166968435049057
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.20980973541736603
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.20638155937194824
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.2042439728975296
# -------  Class: aeroplane        AP:   0.4794  -------
# -------  Class: bicycle          AP:   0.1382  -------
# -------  Class: bird             AP:   0.1232  -------
# -------  Class: boat             AP:   0.2522  -------
# -------  Class: bottle           AP:   0.0792  -------
# -------  Class: bus              AP:   0.1092  -------
# -------  Class: car              AP:   0.4625  -------
# -------  Class: cat              AP:   0.2434  -------
# -------  Class: chair            AP:   0.2863  -------
# -------  Class: cow              AP:   0.0827  -------
# -------  Class: diningtable      AP:   0.1696  -------
# -------  Class: dog              AP:   0.1774  -------
# -------  Class: horse            AP:   0.1725  -------
# -------  Class: motorbike        AP:   0.1590  -------
# -------  Class: person           AP:   0.5892  -------
# -------  Class: pottedplant      AP:   0.0941  -------
# -------  Class: sheep            AP:   0.0680  -------
# -------  Class: sofa             AP:   0.1885  -------
# -------  Class: train            AP:   0.2351  -------
# -------  Class: tvmonitor        AP:   0.1379  -------
# mAP: 0.2124
# Avg loss: 0.21590879705606722
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.21238194533905103
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.1988501101732254
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.1940065324306488
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.19030581414699554
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.1885002851486206
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.196767196059227
# -------  Class: aeroplane        AP:   0.5699  -------
# -------  Class: bicycle          AP:   0.1990  -------
# -------  Class: bird             AP:   0.1394  -------
# -------  Class: boat             AP:   0.2829  -------
# -------  Class: bottle           AP:   0.1160  -------
# -------  Class: bus              AP:   0.1387  -------
# -------  Class: car              AP:   0.4858  -------
# -------  Class: cat              AP:   0.2590  -------
# -------  Class: chair            AP:   0.3450  -------
# -------  Class: cow              AP:   0.1356  -------
# -------  Class: diningtable      AP:   0.2484  -------
# -------  Class: dog              AP:   0.2010  -------
# -------  Class: horse            AP:   0.3173  -------
# -------  Class: motorbike        AP:   0.2611  -------
# -------  Class: person           AP:   0.6305  -------
# -------  Class: pottedplant      AP:   0.1224  -------
# -------  Class: sheep            AP:   0.0997  -------
# -------  Class: sofa             AP:   0.2282  -------
# -------  Class: train            AP:   0.2108  -------
# -------  Class: tvmonitor        AP:   0.1569  -------
# mAP: 0.2574
# Avg loss: 0.2013592389868755
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.25737575978626137
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.18566329777240753
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.181706964969635
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.17402978241443634
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.17705734074115753
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.1777549833059311
# -------  Class: aeroplane        AP:   0.5789  -------
# -------  Class: bicycle          AP:   0.2575  -------
# -------  Class: bird             AP:   0.1478  -------
# -------  Class: boat             AP:   0.2974  -------
# -------  Class: bottle           AP:   0.1157  -------
# -------  Class: bus              AP:   0.1261  -------
# -------  Class: car              AP:   0.5122  -------
# -------  Class: cat              AP:   0.2839  -------
# -------  Class: chair            AP:   0.3590  -------
# -------  Class: cow              AP:   0.1375  -------
# -------  Class: diningtable      AP:   0.2976  -------
# -------  Class: dog              AP:   0.2120  -------
# -------  Class: horse            AP:   0.3392  -------
# -------  Class: motorbike        AP:   0.3334  -------
# -------  Class: person           AP:   0.6556  -------
# -------  Class: pottedplant      AP:   0.1808  -------
# -------  Class: sheep            AP:   0.1144  -------
# -------  Class: sofa             AP:   0.2858  -------
# -------  Class: train            AP:   0.2434  -------
# -------  Class: tvmonitor        AP:   0.1811  -------
# mAP: 0.2830
# Avg loss: 0.20354998900609858
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.2829763094784098

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.5733  -------
# -------  Class: bicycle          AP:   0.2384  -------
# -------  Class: bird             AP:   0.1674  -------
# -------  Class: boat             AP:   0.2676  -------
# -------  Class: bottle           AP:   0.1350  -------
# -------  Class: bus              AP:   0.1265  -------
# -------  Class: car              AP:   0.5344  -------
# -------  Class: cat              AP:   0.2307  -------
# -------  Class: chair            AP:   0.3140  -------
# -------  Class: cow              AP:   0.1457  -------
# -------  Class: diningtable      AP:   0.2138  -------
# -------  Class: dog              AP:   0.2242  -------
# -------  Class: horse            AP:   0.4584  -------
# -------  Class: motorbike        AP:   0.2725  -------
# -------  Class: person           AP:   0.6776  -------
# -------  Class: pottedplant      AP:   0.1448  -------
# -------  Class: sheep            AP:   0.1561  -------
# -------  Class: sofa             AP:   0.2631  -------
# -------  Class: train            AP:   0.3103  -------
# -------  Class: tvmonitor        AP:   0.1481  -------
# mAP: 0.2801
# Avg loss: 0.19845137283205985
# Test mAP:  0.28009245217655104

# %% [markdown]
# You should notice somewhat poor performance. You could try running AlexNet with an Adam optimizer instead with learning rate 1e-4 to see if that makes a difference. This experiment is not required for the writeup, but it may show you the importance of a good learning rate and optimizer.

# %% [markdown]
# ## Pretrained AlexNet

# %% [markdown]
# Here we look at the impact of pretrained features. This model's weights were trained on ImageNet, which is a much larger dataset. How do pretrained features perform on VOC? Why do you think there is such a large difference in performance?

# %%
num_epochs = 20
test_frequency = 5

# Load Pretrained AlexNet
classifier = torchvision.models.alexnet(pretrained=True)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.21974310278892517
# -------  Class: aeroplane        AP:   0.7537  -------
# -------  Class: bicycle          AP:   0.6145  -------
# -------  Class: bird             AP:   0.8148  -------
# -------  Class: boat             AP:   0.6196  -------
# -------  Class: bottle           AP:   0.3277  -------
# -------  Class: bus              AP:   0.5099  -------
# -------  Class: car              AP:   0.7715  -------
# -------  Class: cat              AP:   0.6884  -------
# -------  Class: chair            AP:   0.5796  -------
# -------  Class: cow              AP:   0.3034  -------
# -------  Class: diningtable      AP:   0.5094  -------
# -------  Class: dog              AP:   0.5996  -------
# -------  Class: horse            AP:   0.6308  -------
# -------  Class: motorbike        AP:   0.6905  -------
# -------  Class: person           AP:   0.8959  -------
# -------  Class: pottedplant      AP:   0.2979  -------
# -------  Class: sheep            AP:   0.2759  -------
# -------  Class: sofa             AP:   0.4558  -------
# -------  Class: train            AP:   0.7844  -------
# -------  Class: tvmonitor        AP:   0.5694  -------
# mAP: 0.5846
# Avg loss: 0.13821526383068047
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.5846439079971271
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.12543831765651703
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.10820016264915466
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.09251093864440918
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.08806419372558594
# -------  Class: aeroplane        AP:   0.8352  -------
# -------  Class: bicycle          AP:   0.7240  -------
# -------  Class: bird             AP:   0.8710  -------
# -------  Class: boat             AP:   0.7801  -------
# -------  Class: bottle           AP:   0.3909  -------
# -------  Class: bus              AP:   0.5921  -------
# -------  Class: car              AP:   0.8312  -------
# -------  Class: cat              AP:   0.7917  -------
# -------  Class: chair            AP:   0.6187  -------
# -------  Class: cow              AP:   0.4617  -------
# -------  Class: diningtable      AP:   0.5787  -------
# -------  Class: dog              AP:   0.7144  -------
# -------  Class: horse            AP:   0.7248  -------
# -------  Class: motorbike        AP:   0.7130  -------
# -------  Class: person           AP:   0.9017  -------
# -------  Class: pottedplant      AP:   0.4562  -------
# -------  Class: sheep            AP:   0.5896  -------
# -------  Class: sofa             AP:   0.5107  -------
# -------  Class: train            AP:   0.8944  -------
# -------  Class: tvmonitor        AP:   0.6401  -------
# mAP: 0.6810
# Avg loss: 0.11938284688136157
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.6810157878465742
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.0764450803399086
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.09013694524765015
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.0659470185637474
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.05410933867096901
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.05093884468078613
# -------  Class: aeroplane        AP:   0.8512  -------
# -------  Class: bicycle          AP:   0.7218  -------
# -------  Class: bird             AP:   0.8606  -------
# -------  Class: boat             AP:   0.7514  -------
# -------  Class: bottle           AP:   0.3742  -------
# -------  Class: bus              AP:   0.5837  -------
# -------  Class: car              AP:   0.8258  -------
# -------  Class: cat              AP:   0.7720  -------
# -------  Class: chair            AP:   0.6215  -------
# -------  Class: cow              AP:   0.5037  -------
# -------  Class: diningtable      AP:   0.5772  -------
# -------  Class: dog              AP:   0.7226  -------
# -------  Class: horse            AP:   0.7570  -------
# -------  Class: motorbike        AP:   0.7957  -------
# -------  Class: person           AP:   0.9014  -------
# -------  Class: pottedplant      AP:   0.4264  -------
# -------  Class: sheep            AP:   0.6262  -------
# -------  Class: sofa             AP:   0.5130  -------
# -------  Class: train            AP:   0.8560  -------
# -------  Class: tvmonitor        AP:   0.6260  -------
# mAP: 0.6834
# Avg loss: 0.13881447692127788
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.6833779148880058
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.05961771681904793
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.07502993941307068
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.05894027277827263
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.037942398339509964
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.03337923809885979
# -------  Class: aeroplane        AP:   0.8422  -------
# -------  Class: bicycle          AP:   0.7121  -------
# -------  Class: bird             AP:   0.8562  -------
# -------  Class: boat             AP:   0.7272  -------
# -------  Class: bottle           AP:   0.3511  -------
# -------  Class: bus              AP:   0.5364  -------
# -------  Class: car              AP:   0.8001  -------
# -------  Class: cat              AP:   0.7822  -------
# -------  Class: chair            AP:   0.5857  -------
# -------  Class: cow              AP:   0.5229  -------
# -------  Class: diningtable      AP:   0.6044  -------
# -------  Class: dog              AP:   0.7160  -------
# -------  Class: horse            AP:   0.7493  -------
# -------  Class: motorbike        AP:   0.7969  -------
# -------  Class: person           AP:   0.9011  -------
# -------  Class: pottedplant      AP:   0.4142  -------
# -------  Class: sheep            AP:   0.5666  -------
# -------  Class: sofa             AP:   0.5127  -------
# -------  Class: train            AP:   0.8552  -------
# -------  Class: tvmonitor        AP:   0.6197  -------
# mAP: 0.6726
# Avg loss: 0.14870461134933957
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.6726174369005837
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.02610884979367256
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.02256917580962181
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.019227275624871254
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.018446167930960655
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.01632346585392952
# -------  Class: aeroplane        AP:   0.8415  -------
# -------  Class: bicycle          AP:   0.7015  -------
# -------  Class: bird             AP:   0.8605  -------
# -------  Class: boat             AP:   0.7228  -------
# -------  Class: bottle           AP:   0.3387  -------
# -------  Class: bus              AP:   0.5518  -------
# -------  Class: car              AP:   0.8093  -------
# -------  Class: cat              AP:   0.7802  -------
# -------  Class: chair            AP:   0.5827  -------
# -------  Class: cow              AP:   0.5259  -------
# -------  Class: diningtable      AP:   0.6112  -------
# -------  Class: dog              AP:   0.6909  -------
# -------  Class: horse            AP:   0.7516  -------
# -------  Class: motorbike        AP:   0.8051  -------
# -------  Class: person           AP:   0.9008  -------
# -------  Class: pottedplant      AP:   0.4284  -------
# -------  Class: sheep            AP:   0.5684  -------
# -------  Class: sofa             AP:   0.5178  -------
# -------  Class: train            AP:   0.8533  -------
# -------  Class: tvmonitor        AP:   0.6184  -------
# mAP: 0.6730
# Avg loss: 0.17472684324956408
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.6730464167730865

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.8313  -------
# -------  Class: bicycle          AP:   0.7447  -------
# -------  Class: bird             AP:   0.8347  -------
# -------  Class: boat             AP:   0.7786  -------
# -------  Class: bottle           AP:   0.3323  -------
# -------  Class: bus              AP:   0.6285  -------
# -------  Class: car              AP:   0.8277  -------
# -------  Class: cat              AP:   0.7833  -------
# -------  Class: chair            AP:   0.5645  -------
# -------  Class: cow              AP:   0.4980  -------
# -------  Class: diningtable      AP:   0.6321  -------
# -------  Class: dog              AP:   0.7084  -------
# -------  Class: horse            AP:   0.8312  -------
# -------  Class: motorbike        AP:   0.7571  -------
# -------  Class: person           AP:   0.9147  -------
# -------  Class: pottedplant      AP:   0.4579  -------
# -------  Class: sheep            AP:   0.6322  -------
# -------  Class: sofa             AP:   0.5233  -------
# -------  Class: train            AP:   0.8509  -------
# -------  Class: tvmonitor        AP:   0.6091  -------
# mAP: 0.6870
# Avg loss: 0.16740411646664144
# Test mAP:  0.6870176887007424
